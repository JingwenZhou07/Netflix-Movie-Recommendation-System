# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd "/content/drive/My Drive/Code/gcmc/"
# Out:
# /content/drive/My Drive/Code/gcmc

# %%
# !python setup.py install
# !pip3 install pickle-mixin

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import scipy.sparse as sp
import random
import argparse
import datetime
import time
import os.path

from sklearn.preprocessing import LabelEncoder
from __future__ import division
from __future__ import print_function

import tensorflow.compat.v1 as tf
tf.compat.v1.disable_eager_execution()
import sys
import json

from model import RecommenderGAE, RecommenderSideInfoGAE
from utils import construct_feed_dict

# %%
# Set random seed
# seed = 123 # use only for unit testing
seed = int(time.time())
np.random.seed(seed)
tf.set_random_seed(seed)

NUMCLASSES = 5
FEATURES = False 
SELFCONNECTIONS = False
ACCUM = sum
HIDDEN = [500,75]
DO = 0.7 #dropout
verbose = True

u_features = None
v_features = None

# %%
for dirname, _, filenames in os.walk('./data/netflix'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ./data/netflix/combined_data_1.txt
# ./data/netflix/combined_data_2.txt
# ./data/netflix/combined_data_3.txt
# ./data/netflix/.DS_Store

# %%
# %time

# DataFrame to store all imported data
if not os.path.isfile('./data/netflix/data.csv'):
    data = open('./data/netflix/data.csv', mode='w')

    files = ['./data/netflix/combined_data_1.txt',
            './data/netflix/combined_data_2.txt',
            './data/netflix/combined_data_3.txt'
            #'./data/netflix/combined_data_4.txt'
            ]

    # Remove the line with movie_id: and add a new column of movie_id
    # Combine all data files into a csv file
    for file in files:
      print("Opening file: {}".format(file))
      with open(file) as f:
        for line in f:
            line = line.strip()
            if line.endswith(':'):
                movie_id = line.replace(':', '')
            else:
                data.write(movie_id + ',' + line)
                data.write('\n')
    data.close()
# Out:
# CPU times: user 0 ns, sys: 2 µs, total: 2 µs
# Wall time: 5.72 µs
# Opening file: ./data/netflix/combined_data_1.txt
# Opening file: ./data/netflix/combined_data_2.txt
# Opening file: ./data/netflix/combined_data_3.txt

# %%
# Read all data into a pd dataframe
df = pd.read_csv('./data/netflix/data.csv', names=['movie_id', 'user_id', 'ratings', 'timestamp'])
print(df.nunique())
df
# Out:
# movie_id      13367
# user_id      479453
# ratings           5
# timestamp      2182
# dtype: int64
#           movie_id  user_id  ratings   timestamp
# 0                1  1488844        3  2005-09-06
# 1                1   822109        5  2005-05-13
# 2                1   885013        4  2005-10-19
# 3                1    30878        4  2005-12-26
# 4                1   823519        3  2004-05-03
# ...            ...      ...      ...         ...
# 73632979     13367  2339129        4  2002-10-07
# 73632980     13367    59005        4  2005-01-21
# 73632981     13367  1789683        5  2005-05-25
# 73632982     13367  1878798        1  2003-02-17
# 73632983     13367  2634967        1  2005-01-10
#
# [73632984 rows x 4 columns]

# %%
lite_rating_df = pd.DataFrame()

# 4000 top users (who gave the most rates) - Remove customer who give too less ratings (they are relatively less active)
group = df.groupby('user_id')['ratings'].count()
top_users = group.sort_values(ascending=False)[:4000]

# 2000 top rated movies - Remove movie with too less ratings (they are relatively not popular)
group = df.groupby('movie_id')['ratings'].count()
top_movies = group.sort_values(ascending=False)[:2000]

lite_rating_df = df.join(top_users, rsuffix='_r', how='inner', on='user_id')
lite_rating_df = lite_rating_df.join(top_movies, rsuffix='_r', how='inner', on='movie_id')

# Re-name the users and movies for uniform name from 1..2000 and 4000
user_enc = LabelEncoder()
lite_rating_df['u_nodes'] = user_enc.fit_transform(lite_rating_df['user_id'].values)
movie_enc = LabelEncoder()
lite_rating_df['v_nodes'] = movie_enc.fit_transform(lite_rating_df['movie_id'].values)

n_movies = lite_rating_df['v_nodes'].nunique()
n_users = lite_rating_df['u_nodes'].nunique()

lite_rating_df
#print(n_movies, n_users)
# Out:
#           movie_id  user_id  ratings   timestamp  ratings_r  ratings_r  \
# 5149             8  1488844        4  2005-05-12       1634      14910
# 5883             8  1227322        5  2005-05-31       3552      14910
# 6183             8   525356        4  2005-08-26       3669      14910
# 6310             8   401047        2  2005-06-15       1569      14910
# 7140             8   883478        5  2005-10-10       2391      14910
# ...            ...      ...      ...         ...        ...        ...
# 14084763      2705  1686713        3  2002-10-25       1347       6874
# 14086177      2705   753596        2  2004-05-14       1333       6874
# 14083158      2705  1170335        3  2004-12-12       1442       6874
# 14083299      2705   666500        4  2002-12-18       1132       6874
# 14084155      2705  2222177        3  2005-01-03       1183       6874
#
#           u_nodes  v_nodes
# 5149         2252        0
# 5883         1870        0
# 6183          800        0
# 6310          597        0
# 7140         1330        0
# ...           ...      ...
# 14084763     2546      387
# 14086177     1122      387
# 14083158     1774      387
# 14083299     1000      387
# 14084155     3333      387
#
# [3830633 rows x 8 columns]

# %%
lite_rating_df = lite_rating_df.drop(['movie_id', 'user_id', 'ratings_r', 'timestamp'], axis=1)
lite_rating_df = lite_rating_df[["u_nodes",	"v_nodes", "ratings"]]
lite_rating_df.to_csv('./data/netflix/data_clean.csv',index=False)

# %%
dtypes = {
    'u_nodes': np.int64, 'v_nodes': np.int64,
    'ratings': np.float32}

data = pd.read_csv('./data/netflix/data_clean.csv', converters=dtypes, engine='python')
data
# Out:
#          u_nodes  v_nodes  ratings
# 0           2252        0      4.0
# 1           1870        0      5.0
# 2            800        0      4.0
# 3            597        0      2.0
# 4           1330        0      5.0
# ...          ...      ...      ...
# 3830628     2546      387      3.0
# 3830629     1122      387      2.0
# 3830630     1774      387      3.0
# 3830631     1000      387      4.0
# 3830632     3333      387      3.0
#
# [3830633 rows x 3 columns]

# %%
# make sure to convert to list, otherwise random.shuffle acts weird on it without a warning
data_array = data.values.tolist()
random.seed(seed)
random.shuffle(data_array)
data_array = np.array(data_array)

u_nodes_ratings = data_array[:, 0].astype(dtypes['u_nodes'])
v_nodes_ratings = data_array[:, 1].astype(dtypes['v_nodes'])
ratings = data_array[:, 2].astype(dtypes['ratings'])

# Map data to proper indices in case they are not in a continues [0, N) range
def map_data(data):
  uniq = list(set(data))

  id_dict = {old: new for new, old in enumerate(sorted(uniq))}
  data = np.array(list(map(lambda x: id_dict[x], data)))
  n = len(uniq)

  return data, id_dict, n

u_nodes_ratings, u_dict, num_users = map_data(u_nodes_ratings)
v_nodes_ratings, v_dict, num_items = map_data(v_nodes_ratings)

u_nodes_ratings = u_nodes_ratings.astype(np.int64)
v_nodes_ratings = v_nodes_ratings.astype(np.int64)
ratings = ratings.astype(np.float32)

if verbose:
    print('Number of users = %d' % num_users)
    print('Number of items = %d' % num_items)
    print('Number of links = %d' % ratings.shape[0])
    print('Fraction of positive links = %.4f' % (float(ratings.shape[0]) / (num_users * num_items),))
# Out:
# Number of users = 4000
# Number of items = 2000
# Number of links = 3830633
# Fraction of positive links = 0.4788

# %%
import pickle as pkl
datasplit_path = 'data/' + 'netflix' + '/split_seed' + str('netflix') + '.pickle'

with open(datasplit_path, 'wb+') as f:
    pkl.dump([num_users, num_items, u_nodes_ratings, v_nodes_ratings, ratings, u_features, v_features], f)

neutral_rating = -1

rating_dict = {r: i for i, r in enumerate(np.sort(np.unique(ratings)).tolist())}

labels = np.full((num_users, num_items), neutral_rating, dtype=np.int32)
labels[u_nodes_ratings, v_nodes_ratings] = np.array([rating_dict[r] for r in ratings])
labels = labels.reshape([-1])

# number of test and validation edges
num_test = int(np.ceil(ratings.shape[0] * 0.1))
num_val = int(np.ceil(ratings.shape[0] * 0.9 * 0.05))

num_train = ratings.shape[0] - num_val - num_test

pairs_nonzero = np.array([[u, v] for u, v in zip(u_nodes_ratings, v_nodes_ratings)])

idx_nonzero = np.array([u * num_items + v for u, v in pairs_nonzero])

train_idx = idx_nonzero[0:num_train]
val_idx = idx_nonzero[num_train:num_train + num_val]
test_idx = idx_nonzero[num_train + num_val:]

train_pairs_idx = pairs_nonzero[0:num_train]
val_pairs_idx = pairs_nonzero[num_train:num_train + num_val]
test_pairs_idx = pairs_nonzero[num_train + num_val:]

u_test_idx, v_test_idx = test_pairs_idx.transpose()
u_val_idx, v_val_idx = val_pairs_idx.transpose()
u_train_idx, v_train_idx = train_pairs_idx.transpose()

# create labels
train_labels = labels[train_idx]
val_labels = labels[val_idx]
test_labels = labels[test_idx]


#testing==true
u_train_idx = np.hstack([u_train_idx, u_val_idx])
v_train_idx = np.hstack([v_train_idx, v_val_idx])
train_labels = np.hstack([train_labels, val_labels])
# for adjacency matrix construction
train_idx = np.hstack([train_idx, val_idx])

# make training adjacency matrix
rating_mx_train = np.zeros(num_users * num_items, dtype=np.float32)
rating_mx_train[train_idx] = labels[train_idx].astype(np.float32) + 1.
rating_mx_train = sp.csr_matrix(rating_mx_train.reshape(num_users, num_items))

class_values = np.sort(np.unique(ratings))
rating_mx_train
# Out:
# <4000x2000 sparse matrix of type '<class 'numpy.float32'>'
# 	with 3447569 stored elements in Compressed Sparse Row format>

# %%
adj_train = rating_mx_train
train_u_indices = u_train_idx
train_v_indices = v_train_idx
val_u_indices = u_val_idx
val_v_indices = v_val_idx
test_u_indices = u_test_idx
test_v_indices = v_test_idx

num_users, num_items = adj_train.shape
num_side_features = 0

def preprocess_user_item_features(u_features, v_features):
    """
    Creates one big feature matrix out of user features and item features.
    Stacks item features under the user features.
    """

    zero_csr_u = sp.csr_matrix((u_features.shape[0], v_features.shape[1]), dtype=u_features.dtype)
    zero_csr_v = sp.csr_matrix((v_features.shape[0], u_features.shape[1]), dtype=v_features.dtype)

    u_features = sp.hstack([u_features, zero_csr_u], format='csr')
    v_features = sp.hstack([zero_csr_v, v_features], format='csr')

    return u_features, v_features

# no Features: Netflix dataset 

# scipy.sparse.identity(n, dtype='d', format=None) 
u_features = sp.identity(num_users, format='csr')
v_features = sp.identity(num_items, format='csr')

u_features, v_features = preprocess_user_item_features(u_features, v_features)

# global normalization
support = []
support_t = []
adj_train_int = sp.csr_matrix(adj_train, dtype=np.int32)

for i in range(NUMCLASSES):
    # build individual binary rating matrices (supports) for each rating
    support_unnormalized = sp.csr_matrix(adj_train_int == i + 1, dtype=np.float32)

    if support_unnormalized.nnz == 0 :
        # yahoo music has dataset split with not all ratings types present in training set.
        # this produces empty adjacency matrices for these ratings.
        sys.exit('ERROR: normalized bipartite adjacency matrix has only zero entries!!!!!')

    support_unnormalized_transpose = support_unnormalized.T
    support.append(support_unnormalized)
    support_t.append(support_unnormalized_transpose)

def globally_normalize_bipartite_adjacency(adjacencies, verbose=False, symmetric=True): #来自 preprocessing.py
    """ Globally Normalizes set of bipartite adjacency matrices """

    if verbose:
        print('Symmetrically normalizing bipartite adj')
    # degree_u and degree_v are row and column sums of adj+I

    adj_tot = np.sum(adj for adj in adjacencies)
    degree_u = np.asarray(adj_tot.sum(1)).flatten()
    degree_v = np.asarray(adj_tot.sum(0)).flatten()

    # set zeros to inf to avoid dividing by zero
    degree_u[degree_u == 0.] = np.inf
    degree_v[degree_v == 0.] = np.inf

    degree_u_inv_sqrt = 1. / np.sqrt(degree_u)
    degree_v_inv_sqrt = 1. / np.sqrt(degree_v)
    degree_u_inv_sqrt_mat = sp.diags([degree_u_inv_sqrt], [0])
    degree_v_inv_sqrt_mat = sp.diags([degree_v_inv_sqrt], [0])

    degree_u_inv = degree_u_inv_sqrt_mat.dot(degree_u_inv_sqrt_mat)

    if symmetric:
        adj_norm = [degree_u_inv_sqrt_mat.dot(adj).dot(degree_v_inv_sqrt_mat) for adj in adjacencies]

    else:
        adj_norm = [degree_u_inv.dot(adj) for adj in adjacencies]

    return adj_norm

support = globally_normalize_bipartite_adjacency(support, symmetric=True)
support_t = globally_normalize_bipartite_adjacency(support_t, symmetric=True)

# SELFCONNECTIONS = False
if SELFCONNECTIONS:
    support.append(sp.identity(u_features.shape[0], format='csr'))
    support_t.append(sp.identity(v_features.shape[0], format='csr'))

num_support = len(support)
support = sp.hstack(support, format='csr')
support_t = sp.hstack(support_t, format='csr')

# Collect all user and item nodes for test set
test_u = list(set(test_u_indices))
test_v = list(set(test_v_indices))
test_u_dict = {n: i for i, n in enumerate(test_u)}
test_v_dict = {n: i for i, n in enumerate(test_v)}

test_u_indices = np.array([test_u_dict[o] for o in test_u_indices])
test_v_indices = np.array([test_v_dict[o] for o in test_v_indices])

test_support = support[np.array(test_u)]
test_support_t = support_t[np.array(test_v)]

# Collect all user and item nodes for validation set
val_u = list(set(val_u_indices))
val_v = list(set(val_v_indices))
val_u_dict = {n: i for i, n in enumerate(val_u)}
val_v_dict = {n: i for i, n in enumerate(val_v)}

val_u_indices = np.array([val_u_dict[o] for o in val_u_indices])
val_v_indices = np.array([val_v_dict[o] for o in val_v_indices])

val_support = support[np.array(val_u)]
val_support_t = support_t[np.array(val_v)]

# Collect all user and item nodes for train set
train_u = list(set(train_u_indices))
train_v = list(set(train_v_indices))
train_u_dict = {n: i for i, n in enumerate(train_u)}
train_v_dict = {n: i for i, n in enumerate(train_v)}

train_u_indices = np.array([train_u_dict[o] for o in train_u_indices])
train_v_indices = np.array([train_v_dict[o] for o in train_v_indices])

train_support = support[np.array(train_u)]
train_support_t = support_t[np.array(train_v)]

# no features as side info ：Netflix has not side features

test_u_features_side = None
test_v_features_side = None

val_u_features_side = None
val_v_features_side = None

train_u_features_side = None
train_v_features_side = None

placeholders = {
    'u_features': tf.sparse_placeholder(tf.float32, shape=np.array(u_features.shape, dtype=np.int64)),
    'v_features': tf.sparse_placeholder(tf.float32, shape=np.array(v_features.shape, dtype=np.int64)),
    'u_features_nonzero': tf.placeholder(tf.int32, shape=()),
    'v_features_nonzero': tf.placeholder(tf.int32, shape=()),
    'labels': tf.placeholder(tf.int32, shape=(None,)),

    'u_features_side': tf.placeholder(tf.float32, shape=(None, num_side_features)),
    'v_features_side': tf.placeholder(tf.float32, shape=(None, num_side_features)),

    'user_indices': tf.placeholder(tf.int32, shape=(None,)),
    'item_indices': tf.placeholder(tf.int32, shape=(None,)),

    'class_values': tf.placeholder(tf.float32, shape=class_values.shape),

    'dropout': tf.placeholder_with_default(0., shape=()),
    'weight_decay': tf.placeholder_with_default(0., shape=()),

    'support': tf.sparse_placeholder(tf.float32, shape=(None, None)),
    'support_t': tf.sparse_placeholder(tf.float32, shape=(None, None)),
}

model = RecommenderGAE(placeholders,
                           input_dim=u_features.shape[1],
                           num_classes=NUMCLASSES,
                           num_support=num_support,
                           self_connections=SELFCONNECTIONS,
                           num_basis_functions=2,
                           hidden=HIDDEN,
                           num_users=num_users,
                           num_items=num_items,
                           accum="sum",
                           learning_rate=0.01,
                           logging=True)

def sparse_to_tuple(sparse_mx):
    """ change of format for sparse matrix. This format is used
    for the feed_dict where sparse matrices need to be linked to placeholders
    representing sparse matrices. """

    if not sp.isspmatrix_coo(sparse_mx):
        sparse_mx = sparse_mx.tocoo()
    coords = np.vstack((sparse_mx.row, sparse_mx.col)).transpose()
    values = sparse_mx.data
    shape = sparse_mx.shape
    return coords, values, shape

# Convert sparse placeholders to tuples to construct feed_dict
test_support = sparse_to_tuple(test_support)
test_support_t = sparse_to_tuple(test_support_t)

val_support = sparse_to_tuple(val_support)
val_support_t = sparse_to_tuple(val_support_t)

train_support = sparse_to_tuple(train_support)
train_support_t = sparse_to_tuple(train_support_t)

u_features = sparse_to_tuple(u_features)
v_features = sparse_to_tuple(v_features)
assert u_features[2][1] == v_features[2][1], 'Number of features of users and items must be the same!'

num_features = u_features[2][1]
u_features_nonzero = u_features[1].shape[0]
v_features_nonzero = v_features[1].shape[0]

# Feed_dicts for validation and test set stay constant over different update steps
train_feed_dict = construct_feed_dict(placeholders, u_features, v_features, u_features_nonzero,
                                      v_features_nonzero, train_support, train_support_t,
                                      train_labels, train_u_indices, train_v_indices, class_values, DO,
                                      train_u_features_side, train_v_features_side)
# No dropout for validation and test runs
val_feed_dict = construct_feed_dict(placeholders, u_features, v_features, u_features_nonzero,
                                    v_features_nonzero, val_support, val_support_t,
                                    val_labels, val_u_indices, val_v_indices, class_values, 0.,
                                    val_u_features_side, val_v_features_side)

test_feed_dict = construct_feed_dict(placeholders, u_features, v_features, u_features_nonzero,
                                     v_features_nonzero, test_support, test_support_t,
                                     test_labels, test_u_indices, test_v_indices, class_values, 0.,
                                     test_u_features_side, test_v_features_side)

# Collect all variables to be logged into summary
merged_summary = tf.summary.merge_all()

sess = tf.Session()
sess.run(tf.global_variables_initializer())

train_summary_writer = None
val_summary_writer = None

best_val_score = np.inf
best_val_loss = np.inf
best_epoch = 0
wait = 0
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:59: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:59: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradients/bilinearmixture_1/GatherV2_1_grad/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradients/bilinearmixture_1/GatherV2_1_grad/Reshape:0", shape=(None, 75), dtype=float32), dense_shape=Tensor("gradients/bilinearmixture_1/GatherV2_1_grad/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradients/bilinearmixture_1/GatherV2_grad/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradients/bilinearmixture_1/GatherV2_grad/Reshape:0", shape=(None, 75), dtype=float32), dense_shape=Tensor("gradients/bilinearmixture_1/GatherV2_grad/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/moving_averages.py:548: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.

# %%
print('Training...')
NB_EPOCH = 3500
TESTING = True
for epoch in range(NB_EPOCH):

    t = time.time()

    # Run single weight update
    # outs = sess.run([model.opt_op, model.loss, model.rmse], feed_dict=train_feed_dict)
    # with exponential moving averages
    outs = sess.run([model.training_op, model.loss, model.rmse], feed_dict=train_feed_dict)

    train_avg_loss = outs[1]
    train_rmse = outs[2]

    val_avg_loss, val_rmse = sess.run([model.loss, model.rmse], feed_dict=val_feed_dict)

    
    print("[*] Epoch:", '%04d' % (epoch + 1), "train_loss=", "{:.5f}".format(train_avg_loss),
          "train_rmse=", "{:.5f}".format(train_rmse),
          "val_loss=", "{:.5f}".format(val_avg_loss),
          "val_rmse=", "{:.5f}".format(val_rmse),
          "\t\ttime=", "{:.5f}".format(time.time() - t))

    if val_rmse < best_val_score:
        best_val_score = val_rmse
        best_epoch = epoch


    if epoch % 100 == 0 and epoch > 1000 and not TESTING and False:
        saver = tf.train.Saver()
        save_path = saver.save(sess, "tmp/%s_seed%d.ckpt" % (model.name, DATASEED), global_step=model.global_step)

        # load polyak averages
        variables_to_restore = model.variable_averages.variables_to_restore()
        saver = tf.train.Saver(variables_to_restore)
        saver.restore(sess, save_path)

        val_avg_loss, val_rmse = sess.run([model.loss, model.rmse], feed_dict=val_feed_dict)

        print('polyak val loss = ', val_avg_loss)
        print('polyak val rmse = ', val_rmse)

        # Load back normal variables
        saver = tf.train.Saver()
        saver.restore(sess, save_path)
# Out:
# Training...
# [*] Epoch: 0001 train_loss= 1.60944 train_rmse= 1.16769 val_loss= 1.60942 val_rmse= 1.16681 		time= 5.33231
# [*] Epoch: 0002 train_loss= 1.60943 train_rmse= 1.16766 val_loss= 1.60918 val_rmse= 1.16626 		time= 2.76315
# [*] Epoch: 0003 train_loss= 1.60929 train_rmse= 1.16736 val_loss= 1.60437 val_rmse= 1.15543 		time= 2.80995
# [*] Epoch: 0004 train_loss= 1.60700 train_rmse= 1.16228 val_loss= 1.57459 val_rmse= 1.06314 		time= 2.82489
# [*] Epoch: 0005 train_loss= 1.58549 train_rmse= 1.11263 val_loss= 2.26174 val_rmse= 1.44943 		time= 2.79521
# [*] Epoch: 0006 train_loss= 1.63990 train_rmse= 1.09622 val_loss= 1.61240 val_rmse= 1.08779 		time= 2.80244
# [*] Epoch: 0007 train_loss= 1.53392 train_rmse= 1.06043 val_loss= 1.56876 val_rmse= 1.14728 		time= 2.75282
# [*] Epoch: 0008 train_loss= 1.54152 train_rmse= 1.14381 val_loss= 1.63684 val_rmse= 1.17666 		time= 2.75639
# [*] Epoch: 0009 train_loss= 1.55537 train_rmse= 1.16892 val_loss= 1.54319 val_rmse= 1.12730 		time= 2.75557
# [*] Epoch: 0010 train_loss= 1.53058 train_rmse= 1.13220 val_loss= 1.53638 val_rmse= 1.08073 		time= 2.78081
# [*] Epoch: 0011 train_loss= 1.50184 train_rmse= 1.08281 val_loss= 1.78002 val_rmse= 1.12241 		time= 2.82436
# [*] Epoch: 0012 train_loss= 1.51956 train_rmse= 1.07105 val_loss= 1.80196 val_rmse= 1.10185 		time= 2.78487
# [*] Epoch: 0013 train_loss= 1.49290 train_rmse= 1.07716 val_loss= 1.65883 val_rmse= 1.10526 		time= 2.78847
# [*] Epoch: 0014 train_loss= 1.47883 train_rmse= 1.09108 val_loss= 1.50773 val_rmse= 1.09142 		time= 2.74837
# [*] Epoch: 0015 train_loss= 1.48593 train_rmse= 1.10161 val_loss= 1.48287 val_rmse= 1.08387 		time= 2.78452
# [*] Epoch: 0016 train_loss= 1.47579 train_rmse= 1.09545 val_loss= 1.52093 val_rmse= 1.07744 		time= 2.76275
# [*] Epoch: 0017 train_loss= 1.45477 train_rmse= 1.08293 val_loss= 1.67367 val_rmse= 1.07607 		time= 2.74519
# [*] Epoch: 0018 train_loss= 1.44018 train_rmse= 1.07414 val_loss= 1.77198 val_rmse= 1.05736 		time= 2.79974
# [*] Epoch: 0019 train_loss= 1.42974 train_rmse= 1.05295 val_loss= 1.72741 val_rmse= 1.04066 		time= 2.78554
# [*] Epoch: 0020 train_loss= 1.46014 train_rmse= 1.04557 val_loss= 1.51311 val_rmse= 1.03932 		time= 2.78318
# [*] Epoch: 0021 train_loss= 1.40023 train_rmse= 1.02972 val_loss= 1.41255 val_rmse= 1.01964 		time= 2.78801
# [*] Epoch: 0022 train_loss= 1.39909 train_rmse= 1.03492 val_loss= 1.51137 val_rmse= 1.04218 		time= 2.76320
# [*] Epoch: 0023 train_loss= 1.41231 train_rmse= 1.07097 val_loss= 1.47709 val_rmse= 1.03367 		time= 2.78266
# [*] Epoch: 0024 train_loss= 1.40723 train_rmse= 1.05609 val_loss= 1.42310 val_rmse= 1.01888 		time= 2.74051
# [*] Epoch: 0025 train_loss= 1.36784 train_rmse= 1.01019 val_loss= 1.60819 val_rmse= 1.09080 		time= 2.72444
# [*] Epoch: 0026 train_loss= 1.43080 train_rmse= 0.99929 val_loss= 1.47878 val_rmse= 1.03474 		time= 2.78022
# [*] Epoch: 0027 train_loss= 1.39791 train_rmse= 0.99802 val_loss= 1.94453 val_rmse= 1.05739 		time= 2.83715
# [*] Epoch: 0028 train_loss= 1.46238 train_rmse= 1.04213 val_loss= 1.78039 val_rmse= 1.04501 		time= 2.76519
# [*] Epoch: 0029 train_loss= 1.40563 train_rmse= 1.01962 val_loss= 1.54554 val_rmse= 1.06335 		time= 2.76788
# [*] Epoch: 0030 train_loss= 1.38943 train_rmse= 1.00272 val_loss= 1.49298 val_rmse= 1.05646 		time= 2.77686
# [*] Epoch: 0031 train_loss= 1.39225 train_rmse= 0.98896 val_loss= 1.40322 val_rmse= 1.01018 		time= 2.74360
# [*] Epoch: 0032 train_loss= 1.35273 train_rmse= 0.99192 val_loss= 1.40932 val_rmse= 1.00257 		time= 2.81220
# [*] Epoch: 0033 train_loss= 1.35641 train_rmse= 0.99494 val_loss= 1.42090 val_rmse= 1.00837 		time= 2.75923
# [*] Epoch: 0034 train_loss= 1.35387 train_rmse= 0.99447 val_loss= 1.45490 val_rmse= 1.02389 		time= 2.79444
# [*] Epoch: 0035 train_loss= 1.36733 train_rmse= 0.98958 val_loss= 1.48492 val_rmse= 1.02078 		time= 2.73538
# [*] Epoch: 0036 train_loss= 1.35657 train_rmse= 0.98613 val_loss= 1.57963 val_rmse= 1.01396 		time= 2.76002
# [*] Epoch: 0037 train_loss= 1.36310 train_rmse= 0.99550 val_loss= 1.60828 val_rmse= 1.01479 		time= 2.79848
# [*] Epoch: 0038 train_loss= 1.35353 train_rmse= 0.99187 val_loss= 1.55444 val_rmse= 1.01255 		time= 2.74505
# [*] Epoch: 0039 train_loss= 1.34167 train_rmse= 0.98420 val_loss= 1.50514 val_rmse= 0.99645 		time= 2.74512
# [*] Epoch: 0040 train_loss= 1.34454 train_rmse= 0.98476 val_loss= 1.44202 val_rmse= 0.97293 		time= 2.81146
# [*] Epoch: 0041 train_loss= 1.34835 train_rmse= 0.98438 val_loss= 1.39600 val_rmse= 0.96402 		time= 2.77148
# [*] Epoch: 0042 train_loss= 1.33610 train_rmse= 0.96983 val_loss= 1.38676 val_rmse= 0.96301 		time= 2.78761
# [*] Epoch: 0043 train_loss= 1.37509 train_rmse= 1.00258 val_loss= 1.47403 val_rmse= 0.99773 		time= 2.79221
# [*] Epoch: 0044 train_loss= 1.32310 train_rmse= 0.96417 val_loss= 1.57443 val_rmse= 1.01630 		time= 2.81278
# [*] Epoch: 0045 train_loss= 1.32722 train_rmse= 0.96580 val_loss= 1.59826 val_rmse= 1.02640 		time= 2.80912
# [*] Epoch: 0046 train_loss= 1.32467 train_rmse= 0.96707 val_loss= 1.50652 val_rmse= 0.99881 		time= 2.83609
# [*] Epoch: 0047 train_loss= 1.33523 train_rmse= 0.97229 val_loss= 1.43900 val_rmse= 0.95436 		time= 2.76485
# [*] Epoch: 0048 train_loss= 1.32683 train_rmse= 0.96718 val_loss= 1.46266 val_rmse= 0.95554 		time= 2.79508
# [*] Epoch: 0049 train_loss= 1.41316 train_rmse= 1.03042 val_loss= 1.39504 val_rmse= 0.96133 		time= 2.78573
# [*] Epoch: 0050 train_loss= 1.31367 train_rmse= 0.95901 val_loss= 1.45512 val_rmse= 1.00487 		time= 2.76963
# [*] Epoch: 0051 train_loss= 1.31172 train_rmse= 0.95783 val_loss= 1.58756 val_rmse= 1.06065 		time= 2.78621
# [*] Epoch: 0052 train_loss= 1.38657 train_rmse= 1.02457 val_loss= 1.50675 val_rmse= 1.00875 		time= 2.73189
# [*] Epoch: 0053 train_loss= 1.34520 train_rmse= 0.98995 val_loss= 1.54073 val_rmse= 0.98095 		time= 2.77468
# [*] Epoch: 0054 train_loss= 1.33895 train_rmse= 0.97509 val_loss= 1.47388 val_rmse= 0.96928 		time= 2.77298
# [*] Epoch: 0055 train_loss= 1.34367 train_rmse= 0.98844 val_loss= 1.38376 val_rmse= 0.96318 		time= 2.77138
# [*] Epoch: 0056 train_loss= 1.35123 train_rmse= 0.99812 val_loss= 1.31586 val_rmse= 0.95691 		time= 2.79199
# [*] Epoch: 0057 train_loss= 1.34180 train_rmse= 0.98192 val_loss= 1.31674 val_rmse= 0.96297 		time= 2.78296
# [*] Epoch: 0058 train_loss= 1.32515 train_rmse= 0.96611 val_loss= 1.36286 val_rmse= 0.98162 		time= 2.82195
# [*] Epoch: 0059 train_loss= 1.33457 train_rmse= 0.96401 val_loss= 1.49326 val_rmse= 0.99845 		time= 2.76990
# [*] Epoch: 0060 train_loss= 1.29738 train_rmse= 0.95655 val_loss= 1.64679 val_rmse= 0.99898 		time= 2.77479
# [*] Epoch: 0061 train_loss= 1.35185 train_rmse= 0.98680 val_loss= 1.61311 val_rmse= 0.96676 		time= 2.75294
# [*] Epoch: 0062 train_loss= 1.32421 train_rmse= 0.96577 val_loss= 1.49155 val_rmse= 0.94781 		time= 2.82777
# [*] Epoch: 0063 train_loss= 1.31147 train_rmse= 0.95450 val_loss= 1.36874 val_rmse= 0.95099 		time= 2.80572
# [*] Epoch: 0064 train_loss= 1.31711 train_rmse= 0.95800 val_loss= 1.33999 val_rmse= 0.96114 		time= 2.86842
# [*] Epoch: 0065 train_loss= 1.34105 train_rmse= 0.97429 val_loss= 1.32925 val_rmse= 0.95540 		time= 2.78237
# [*] Epoch: 0066 train_loss= 1.29692 train_rmse= 0.94916 val_loss= 1.33803 val_rmse= 0.95712 		time= 2.78173
# [*] Epoch: 0067 train_loss= 1.32937 train_rmse= 0.96468 val_loss= 1.35759 val_rmse= 0.94246 		time= 2.77834
# [*] Epoch: 0068 train_loss= 1.28918 train_rmse= 0.94246 val_loss= 1.46897 val_rmse= 0.94529 		time= 2.78033
# [*] Epoch: 0069 train_loss= 1.30714 train_rmse= 0.96344 val_loss= 1.64330 val_rmse= 0.95881 		time= 2.81978
# [*] Epoch: 0070 train_loss= 1.35862 train_rmse= 0.95037 val_loss= 1.52656 val_rmse= 0.97690 		time= 2.77723
# [*] Epoch: 0071 train_loss= 1.35209 train_rmse= 0.97811 val_loss= 1.35372 val_rmse= 0.96395 		time= 2.80504
# [*] Epoch: 0072 train_loss= 1.28192 train_rmse= 0.94256 val_loss= 1.29278 val_rmse= 0.95163 		time= 2.82133
# [*] Epoch: 0073 train_loss= 1.29965 train_rmse= 0.94228 val_loss= 1.27519 val_rmse= 0.94054 		time= 2.79811
# [*] Epoch: 0074 train_loss= 1.32860 train_rmse= 0.96011 val_loss= 1.27399 val_rmse= 0.93783 		time= 2.79316
# [*] Epoch: 0075 train_loss= 1.30982 train_rmse= 0.94517 val_loss= 1.29648 val_rmse= 0.93489 		time= 2.75012
# [*] Epoch: 0076 train_loss= 1.32203 train_rmse= 0.95734 val_loss= 1.40661 val_rmse= 0.93771 		time= 2.79099
# [*] Epoch: 0077 train_loss= 1.29811 train_rmse= 0.94252 val_loss= 1.49792 val_rmse= 0.94549 		time= 2.78665
# [*] Epoch: 0078 train_loss= 1.30301 train_rmse= 0.94908 val_loss= 1.50443 val_rmse= 0.94656 		time= 2.83450
# [*] Epoch: 0079 train_loss= 1.33256 train_rmse= 0.96573 val_loss= 1.42017 val_rmse= 0.93852 		time= 2.80677
# [*] Epoch: 0080 train_loss= 1.29510 train_rmse= 0.95022 val_loss= 1.39537 val_rmse= 0.94079 		time= 2.73482
# [*] Epoch: 0081 train_loss= 1.30277 train_rmse= 0.96559 val_loss= 1.38601 val_rmse= 0.94873 		time= 2.82620
# [*] Epoch: 0082 train_loss= 1.30149 train_rmse= 0.96412 val_loss= 1.36733 val_rmse= 0.93683 		time= 2.74662
# [*] Epoch: 0083 train_loss= 1.28822 train_rmse= 0.94702 val_loss= 1.34573 val_rmse= 0.94233 		time= 2.75325
# [*] Epoch: 0084 train_loss= 1.28652 train_rmse= 0.94566 val_loss= 1.37365 val_rmse= 0.96297 		time= 2.78212
# [*] Epoch: 0085 train_loss= 1.28950 train_rmse= 0.94939 val_loss= 1.37916 val_rmse= 0.95932 		time= 2.76382
# [*] Epoch: 0086 train_loss= 1.28546 train_rmse= 0.94667 val_loss= 1.40806 val_rmse= 0.94736 		time= 2.81518
# [*] Epoch: 0087 train_loss= 1.31254 train_rmse= 0.94834 val_loss= 1.56295 val_rmse= 0.94048 		time= 2.80269
# [*] Epoch: 0088 train_loss= 1.31758 train_rmse= 0.96138 val_loss= 1.60549 val_rmse= 0.94751 		time= 2.79955
# [*] Epoch: 0089 train_loss= 1.29421 train_rmse= 0.94398 val_loss= 1.58403 val_rmse= 0.97573 		time= 2.77282
# [*] Epoch: 0090 train_loss= 1.31487 train_rmse= 0.96977 val_loss= 1.49183 val_rmse= 0.96445 		time= 2.79409
# [*] Epoch: 0091 train_loss= 1.28147 train_rmse= 0.94525 val_loss= 1.37983 val_rmse= 0.93937 		time= 2.75127
# [*] Epoch: 0092 train_loss= 1.26853 train_rmse= 0.93450 val_loss= 1.32054 val_rmse= 0.92698 		time= 2.81467
# [*] Epoch: 0093 train_loss= 1.30957 train_rmse= 0.93716 val_loss= 1.37182 val_rmse= 0.94123 		time= 2.81412
# [*] Epoch: 0094 train_loss= 1.30998 train_rmse= 0.97013 val_loss= 1.39715 val_rmse= 0.93999 		time= 2.78348
# [*] Epoch: 0095 train_loss= 1.39220 train_rmse= 1.00324 val_loss= 1.29936 val_rmse= 0.93455 		time= 2.72903
# [*] Epoch: 0096 train_loss= 1.29422 train_rmse= 0.93183 val_loss= 1.38579 val_rmse= 0.98802 		time= 2.74788
# [*] Epoch: 0097 train_loss= 1.29287 train_rmse= 0.94850 val_loss= 1.45083 val_rmse= 1.00788 		time= 2.80208
# [*] Epoch: 0098 train_loss= 1.32454 train_rmse= 0.97606 val_loss= 1.44061 val_rmse= 0.96999 		time= 2.79795
# [*] Epoch: 0099 train_loss= 1.29923 train_rmse= 0.94353 val_loss= 1.55957 val_rmse= 0.94934 		time= 2.93764
# [*] Epoch: 0100 train_loss= 1.29986 train_rmse= 0.94495 val_loss= 1.56932 val_rmse= 0.93847 		time= 2.84693
# [*] Epoch: 0101 train_loss= 1.29406 train_rmse= 0.94946 val_loss= 1.49648 val_rmse= 0.93001 		time= 2.79149
# [*] Epoch: 0102 train_loss= 1.31004 train_rmse= 0.93275 val_loss= 1.32838 val_rmse= 0.93604 		time= 2.74710
# [*] Epoch: 0103 train_loss= 1.29204 train_rmse= 0.95750 val_loss= 1.29882 val_rmse= 0.94720 		time= 2.83285
# [*] Epoch: 0104 train_loss= 1.30370 train_rmse= 0.94053 val_loss= 1.38604 val_rmse= 0.99165 		time= 3.04391
# [*] Epoch: 0105 train_loss= 1.30256 train_rmse= 0.93105 val_loss= 1.45505 val_rmse= 1.01796 		time= 2.79310
# [*] Epoch: 0106 train_loss= 1.32293 train_rmse= 0.94503 val_loss= 1.47689 val_rmse= 1.01327 		time= 2.79822
# [*] Epoch: 0107 train_loss= 1.32463 train_rmse= 0.94107 val_loss= 1.46321 val_rmse= 0.96227 		time= 2.75485
# [*] Epoch: 0108 train_loss= 1.27607 train_rmse= 0.93497 val_loss= 1.54235 val_rmse= 0.93852 		time= 2.83573
# [*] Epoch: 0109 train_loss= 1.29819 train_rmse= 0.95192 val_loss= 1.57988 val_rmse= 0.93922 		time= 2.82558
# [*] Epoch: 0110 train_loss= 1.32140 train_rmse= 0.93628 val_loss= 1.42189 val_rmse= 0.93972 		time= 2.78155
# [*] Epoch: 0111 train_loss= 1.27990 train_rmse= 0.94331 val_loss= 1.39685 val_rmse= 0.96192 		time= 2.79864
# [*] Epoch: 0112 train_loss= 1.27310 train_rmse= 0.93779 val_loss= 1.39019 val_rmse= 0.97641 		time= 2.77314
# [*] Epoch: 0113 train_loss= 1.27043 train_rmse= 0.93361 val_loss= 1.37774 val_rmse= 0.97653 		time= 2.75675
# [*] Epoch: 0114 train_loss= 1.27966 train_rmse= 0.93312 val_loss= 1.36202 val_rmse= 0.96141 		time= 2.78921
# [*] Epoch: 0115 train_loss= 1.29632 train_rmse= 0.93626 val_loss= 1.36222 val_rmse= 0.93314 		time= 2.83660
# [*] Epoch: 0116 train_loss= 1.28457 train_rmse= 0.93186 val_loss= 1.47051 val_rmse= 0.92237 		time= 2.88643
# [*] Epoch: 0117 train_loss= 1.26644 train_rmse= 0.92718 val_loss= 1.60828 val_rmse= 0.93129 		time= 2.78111
# [*] Epoch: 0118 train_loss= 1.30570 train_rmse= 0.94357 val_loss= 1.56645 val_rmse= 0.92941 		time= 2.76450
# [*] Epoch: 0119 train_loss= 1.35177 train_rmse= 0.95553 val_loss= 1.38104 val_rmse= 0.92559 		time= 2.86507
# [*] Epoch: 0120 train_loss= 1.27678 train_rmse= 0.93955 val_loss= 1.41720 val_rmse= 0.97852 		time= 2.82669
# [*] Epoch: 0121 train_loss= 1.27849 train_rmse= 0.94110 val_loss= 1.44180 val_rmse= 1.01796 		time= 2.90544
# [*] Epoch: 0122 train_loss= 1.31459 train_rmse= 0.95337 val_loss= 1.38173 val_rmse= 0.99896 		time= 2.79554
# [*] Epoch: 0123 train_loss= 1.33639 train_rmse= 0.97173 val_loss= 1.27629 val_rmse= 0.93933 		time= 2.77702
# [*] Epoch: 0124 train_loss= 1.32212 train_rmse= 0.94598 val_loss= 1.25831 val_rmse= 0.92050 		time= 2.80901
# [*] Epoch: 0125 train_loss= 1.27859 train_rmse= 0.92775 val_loss= 1.29087 val_rmse= 0.91562 		time= 2.81038
# [*] Epoch: 0126 train_loss= 1.28619 train_rmse= 0.94703 val_loss= 1.38485 val_rmse= 0.91910 		time= 2.77051
# [*] Epoch: 0127 train_loss= 1.29843 train_rmse= 0.94015 val_loss= 1.41126 val_rmse= 0.92065 		time= 2.81708
# [*] Epoch: 0128 train_loss= 1.25506 train_rmse= 0.92332 val_loss= 1.42245 val_rmse= 0.92602 		time= 2.79937
# [*] Epoch: 0129 train_loss= 1.25298 train_rmse= 0.92231 val_loss= 1.43757 val_rmse= 0.93543 		time= 2.78125
# [*] Epoch: 0130 train_loss= 1.26702 train_rmse= 0.93220 val_loss= 1.45157 val_rmse= 0.94961 		time= 2.78173
# [*] Epoch: 0131 train_loss= 1.25981 train_rmse= 0.92888 val_loss= 1.48204 val_rmse= 0.96413 		time= 2.86034
# [*] Epoch: 0132 train_loss= 1.27878 train_rmse= 0.93465 val_loss= 1.51217 val_rmse= 0.96284 		time= 2.81263
# [*] Epoch: 0133 train_loss= 1.30872 train_rmse= 0.94803 val_loss= 1.39885 val_rmse= 0.93759 		time= 2.78689
# [*] Epoch: 0134 train_loss= 1.26162 train_rmse= 0.93097 val_loss= 1.35044 val_rmse= 0.92337 		time= 2.75978
# [*] Epoch: 0135 train_loss= 1.28605 train_rmse= 0.95062 val_loss= 1.35521 val_rmse= 0.92250 		time= 2.78102
# [*] Epoch: 0136 train_loss= 1.25487 train_rmse= 0.92527 val_loss= 1.37932 val_rmse= 0.92779 		time= 2.84471
# [*] Epoch: 0137 train_loss= 1.26746 train_rmse= 0.92818 val_loss= 1.45761 val_rmse= 0.93670 		time= 2.77497
# [*] Epoch: 0138 train_loss= 1.30963 train_rmse= 0.93418 val_loss= 1.37852 val_rmse= 0.93603 		time= 2.74040
# [*] Epoch: 0139 train_loss= 1.27185 train_rmse= 0.93842 val_loss= 1.36932 val_rmse= 0.94566 		time= 2.73775
# [*] Epoch: 0140 train_loss= 1.29654 train_rmse= 0.95090 val_loss= 1.35719 val_rmse= 0.93315 		time= 2.75866
# [*] Epoch: 0141 train_loss= 1.26276 train_rmse= 0.93115 val_loss= 1.36408 val_rmse= 0.93326 		time= 2.82664
# [*] Epoch: 0142 train_loss= 1.26582 train_rmse= 0.92442 val_loss= 1.33154 val_rmse= 0.93187 		time= 2.82027
# [*] Epoch: 0143 train_loss= 1.24498 train_rmse= 0.91361 val_loss= 1.33903 val_rmse= 0.94225 		time= 2.76302
# [*] Epoch: 0144 train_loss= 1.25278 train_rmse= 0.91849 val_loss= 1.33887 val_rmse= 0.94034 		time= 2.76064
# [*] Epoch: 0145 train_loss= 1.25404 train_rmse= 0.91189 val_loss= 1.36161 val_rmse= 0.93580 		time= 2.77423
# [*] Epoch: 0146 train_loss= 1.24841 train_rmse= 0.91291 val_loss= 1.41568 val_rmse= 0.93333 		time= 2.78147
# [*] Epoch: 0147 train_loss= 1.27039 train_rmse= 0.93198 val_loss= 1.48895 val_rmse= 0.92134 		time= 2.77009
# [*] Epoch: 0148 train_loss= 1.25079 train_rmse= 0.91607 val_loss= 1.53479 val_rmse= 0.91726 		time= 2.76745
# [*] Epoch: 0149 train_loss= 1.28168 train_rmse= 0.94469 val_loss= 1.58782 val_rmse= 0.91418 		time= 2.72993
# [*] Epoch: 0150 train_loss= 1.25666 train_rmse= 0.91320 val_loss= 1.56511 val_rmse= 0.92451 		time= 2.79089
# [*] Epoch: 0151 train_loss= 1.24404 train_rmse= 0.91304 val_loss= 1.51954 val_rmse= 0.93048 		time= 2.77354
# [*] Epoch: 0152 train_loss= 1.26508 train_rmse= 0.92568 val_loss= 1.42512 val_rmse= 0.92472 		time= 2.84223
# [*] Epoch: 0153 train_loss= 1.25039 train_rmse= 0.91451 val_loss= 1.32678 val_rmse= 0.91736 		time= 2.75419
# [*] Epoch: 0154 train_loss= 1.25937 train_rmse= 0.92116 val_loss= 1.28830 val_rmse= 0.91041 		time= 2.79990
# [*] Epoch: 0155 train_loss= 1.25015 train_rmse= 0.91294 val_loss= 1.27928 val_rmse= 0.90687 		time= 2.77764
# [*] Epoch: 0156 train_loss= 1.25539 train_rmse= 0.92165 val_loss= 1.30369 val_rmse= 0.91813 		time= 2.79110
# [*] Epoch: 0157 train_loss= 1.25114 train_rmse= 0.92008 val_loss= 1.31049 val_rmse= 0.91698 		time= 2.85752
# [*] Epoch: 0158 train_loss= 1.25322 train_rmse= 0.91130 val_loss= 1.35893 val_rmse= 0.92110 		time= 2.75695
# [*] Epoch: 0159 train_loss= 1.24164 train_rmse= 0.90565 val_loss= 1.37278 val_rmse= 0.92118 		time= 2.75896
# [*] Epoch: 0160 train_loss= 1.22971 train_rmse= 0.90431 val_loss= 1.38638 val_rmse= 0.91966 		time= 2.80777
# [*] Epoch: 0161 train_loss= 1.25002 train_rmse= 0.91375 val_loss= 1.44787 val_rmse= 0.92157 		time= 2.79457
# [*] Epoch: 0162 train_loss= 1.23908 train_rmse= 0.90719 val_loss= 1.45950 val_rmse= 0.92049 		time= 2.74606
# [*] Epoch: 0163 train_loss= 1.23697 train_rmse= 0.90315 val_loss= 1.41449 val_rmse= 0.92185 		time= 2.80800
# [*] Epoch: 0164 train_loss= 1.25429 train_rmse= 0.92379 val_loss= 1.33836 val_rmse= 0.90944 		time= 2.76073
# [*] Epoch: 0165 train_loss= 1.23000 train_rmse= 0.90280 val_loss= 1.31545 val_rmse= 0.90787 		time= 2.78356
# [*] Epoch: 0166 train_loss= 1.25577 train_rmse= 0.91763 val_loss= 1.33942 val_rmse= 0.91032 		time= 2.78893
# [*] Epoch: 0167 train_loss= 1.23021 train_rmse= 0.90260 val_loss= 1.36936 val_rmse= 0.91761 		time= 2.76990
# [*] Epoch: 0168 train_loss= 1.27748 train_rmse= 0.94519 val_loss= 1.38468 val_rmse= 0.90786 		time= 2.80557
# [*] Epoch: 0169 train_loss= 1.24536 train_rmse= 0.91529 val_loss= 1.42006 val_rmse= 0.90638 		time= 2.77716
# [*] Epoch: 0170 train_loss= 1.22860 train_rmse= 0.90265 val_loss= 1.47768 val_rmse= 0.91054 		time= 2.77001
# [*] Epoch: 0171 train_loss= 1.23602 train_rmse= 0.90487 val_loss= 1.47972 val_rmse= 0.91316 		time= 2.75521
# [*] Epoch: 0172 train_loss= 1.24230 train_rmse= 0.91353 val_loss= 1.45106 val_rmse= 0.92024 		time= 2.79616
# [*] Epoch: 0173 train_loss= 1.23894 train_rmse= 0.90225 val_loss= 1.39504 val_rmse= 0.93091 		time= 2.83131
# [*] Epoch: 0174 train_loss= 1.26495 train_rmse= 0.92815 val_loss= 1.29818 val_rmse= 0.91453 		time= 2.77069
# [*] Epoch: 0175 train_loss= 1.26724 train_rmse= 0.92403 val_loss= 1.27781 val_rmse= 0.91169 		time= 2.78674
# [*] Epoch: 0176 train_loss= 1.30763 train_rmse= 0.91100 val_loss= 1.28731 val_rmse= 0.90473 		time= 2.76532
# [*] Epoch: 0177 train_loss= 1.24022 train_rmse= 0.90598 val_loss= 1.33641 val_rmse= 0.90181 		time= 2.78722
# [*] Epoch: 0178 train_loss= 1.26257 train_rmse= 0.91157 val_loss= 1.46473 val_rmse= 0.90221 		time= 2.81075
# [*] Epoch: 0179 train_loss= 1.26274 train_rmse= 0.91426 val_loss= 1.51177 val_rmse= 0.90021 		time= 2.79433
# [*] Epoch: 0180 train_loss= 1.24559 train_rmse= 0.91035 val_loss= 1.57624 val_rmse= 0.91924 		time= 2.73464
# [*] Epoch: 0181 train_loss= 1.24928 train_rmse= 0.90972 val_loss= 1.61941 val_rmse= 0.95626 		time= 2.75146
# [*] Epoch: 0182 train_loss= 1.25312 train_rmse= 0.90710 val_loss= 1.61948 val_rmse= 1.00501 		time= 2.79407
# [*] Epoch: 0183 train_loss= 1.26757 train_rmse= 0.93299 val_loss= 1.49196 val_rmse= 0.99685 		time= 2.76868
# [*] Epoch: 0184 train_loss= 1.25801 train_rmse= 0.92241 val_loss= 1.34571 val_rmse= 0.95025 		time= 2.74325
# [*] Epoch: 0185 train_loss= 1.27996 train_rmse= 0.91710 val_loss= 1.26306 val_rmse= 0.90590 		time= 2.80385
# [*] Epoch: 0186 train_loss= 1.22884 train_rmse= 0.89790 val_loss= 1.27693 val_rmse= 0.90101 		time= 2.76393
# [*] Epoch: 0187 train_loss= 1.24319 train_rmse= 0.91387 val_loss= 1.32357 val_rmse= 0.91030 		time= 2.82775
# [*] Epoch: 0188 train_loss= 1.28231 train_rmse= 0.93959 val_loss= 1.37272 val_rmse= 0.90847 		time= 2.79482
# [*] Epoch: 0189 train_loss= 1.26256 train_rmse= 0.93048 val_loss= 1.41204 val_rmse= 0.90823 		time= 3.21360
# [*] Epoch: 0190 train_loss= 1.22968 train_rmse= 0.90419 val_loss= 1.48218 val_rmse= 0.91838 		time= 3.19545
# [*] Epoch: 0191 train_loss= 1.24234 train_rmse= 0.91695 val_loss= 1.52091 val_rmse= 0.92280 		time= 2.78715
# [*] Epoch: 0192 train_loss= 1.22612 train_rmse= 0.90378 val_loss= 1.57512 val_rmse= 0.92615 		time= 2.76375
# [*] Epoch: 0193 train_loss= 1.22884 train_rmse= 0.90188 val_loss= 1.57988 val_rmse= 0.93088 		time= 2.76290
# [*] Epoch: 0194 train_loss= 1.24906 train_rmse= 0.90128 val_loss= 1.51107 val_rmse= 0.94664 		time= 2.82852
# [*] Epoch: 0195 train_loss= 1.27013 train_rmse= 0.93522 val_loss= 1.40667 val_rmse= 0.92998 		time= 2.78756
# [*] Epoch: 0196 train_loss= 1.23648 train_rmse= 0.91000 val_loss= 1.34649 val_rmse= 0.91947 		time= 2.77939
# [*] Epoch: 0197 train_loss= 1.23631 train_rmse= 0.90552 val_loss= 1.31044 val_rmse= 0.90162 		time= 2.76440
# [*] Epoch: 0198 train_loss= 1.25661 train_rmse= 0.91665 val_loss= 1.34112 val_rmse= 0.89801 		time= 2.74855
# [*] Epoch: 0199 train_loss= 1.24823 train_rmse= 0.91702 val_loss= 1.42280 val_rmse= 0.90192 		time= 2.74892
# [*] Epoch: 0200 train_loss= 1.23848 train_rmse= 0.90838 val_loss= 1.46959 val_rmse= 0.90761 		time= 2.79944
# [*] Epoch: 0201 train_loss= 1.24393 train_rmse= 0.91463 val_loss= 1.48178 val_rmse= 0.91813 		time= 2.87447
# [*] Epoch: 0202 train_loss= 1.26132 train_rmse= 0.91024 val_loss= 1.41788 val_rmse= 0.93482 		time= 2.79607
# [*] Epoch: 0203 train_loss= 1.23639 train_rmse= 0.91068 val_loss= 1.38094 val_rmse= 0.95078 		time= 2.77895
# [*] Epoch: 0204 train_loss= 1.27621 train_rmse= 0.94138 val_loss= 1.30311 val_rmse= 0.92826 		time= 2.78471
# [*] Epoch: 0205 train_loss= 1.25168 train_rmse= 0.90093 val_loss= 1.28594 val_rmse= 0.91824 		time= 2.79287
# [*] Epoch: 0206 train_loss= 1.26809 train_rmse= 0.90282 val_loss= 1.31933 val_rmse= 0.91488 		time= 2.79163
# [*] Epoch: 0207 train_loss= 1.27939 train_rmse= 0.93507 val_loss= 1.38606 val_rmse= 0.90878 		time= 2.81896
# [*] Epoch: 0208 train_loss= 1.23529 train_rmse= 0.90649 val_loss= 1.46245 val_rmse= 0.90353 		time= 2.84801
# [*] Epoch: 0209 train_loss= 1.25474 train_rmse= 0.90358 val_loss= 1.43786 val_rmse= 0.90284 		time= 2.78714
# [*] Epoch: 0210 train_loss= 1.26290 train_rmse= 0.92210 val_loss= 1.42170 val_rmse= 0.92382 		time= 2.81500
# [*] Epoch: 0211 train_loss= 1.22550 train_rmse= 0.89736 val_loss= 1.45501 val_rmse= 0.96781 		time= 2.78870
# [*] Epoch: 0212 train_loss= 1.24658 train_rmse= 0.91741 val_loss= 1.44370 val_rmse= 0.98432 		time= 2.80866
# [*] Epoch: 0213 train_loss= 1.26765 train_rmse= 0.92867 val_loss= 1.38673 val_rmse= 0.96679 		time= 2.80097
# [*] Epoch: 0214 train_loss= 1.25126 train_rmse= 0.90165 val_loss= 1.35200 val_rmse= 0.94396 		time= 2.78269
# [*] Epoch: 0215 train_loss= 1.25531 train_rmse= 0.90795 val_loss= 1.33584 val_rmse= 0.91708 		time= 2.80188
# [*] Epoch: 0216 train_loss= 1.22772 train_rmse= 0.90146 val_loss= 1.35640 val_rmse= 0.90433 		time= 2.93194
# [*] Epoch: 0217 train_loss= 1.23965 train_rmse= 0.90542 val_loss= 1.35844 val_rmse= 0.89856 		time= 2.83781
# [*] Epoch: 0218 train_loss= 1.22831 train_rmse= 0.90115 val_loss= 1.38278 val_rmse= 0.89760 		time= 2.74458
# [*] Epoch: 0219 train_loss= 1.24049 train_rmse= 0.91632 val_loss= 1.41151 val_rmse= 0.90163 		time= 2.82129
# [*] Epoch: 0220 train_loss= 1.24849 train_rmse= 0.91766 val_loss= 1.46899 val_rmse= 0.90876 		time= 2.81528
# [*] Epoch: 0221 train_loss= 1.25288 train_rmse= 0.92311 val_loss= 1.51466 val_rmse= 0.90515 		time= 2.76674
# [*] Epoch: 0222 train_loss= 1.22033 train_rmse= 0.89605 val_loss= 1.54120 val_rmse= 0.90555 		time= 2.80575
# [*] Epoch: 0223 train_loss= 1.26189 train_rmse= 0.89960 val_loss= 1.42721 val_rmse= 0.90833 		time= 2.78244
# [*] Epoch: 0224 train_loss= 1.22726 train_rmse= 0.90259 val_loss= 1.39521 val_rmse= 0.91787 		time= 2.78846
# [*] Epoch: 0225 train_loss= 1.22120 train_rmse= 0.89856 val_loss= 1.38384 val_rmse= 0.92645 		time= 2.74386
# [*] Epoch: 0226 train_loss= 1.22408 train_rmse= 0.90193 val_loss= 1.39623 val_rmse= 0.93985 		time= 2.76024
# [*] Epoch: 0227 train_loss= 1.22151 train_rmse= 0.89810 val_loss= 1.42011 val_rmse= 0.94832 		time= 2.76371
# [*] Epoch: 0228 train_loss= 1.22334 train_rmse= 0.90023 val_loss= 1.41806 val_rmse= 0.94689 		time= 2.79098
# [*] Epoch: 0229 train_loss= 1.25087 train_rmse= 0.91144 val_loss= 1.39366 val_rmse= 0.92288 		time= 2.77906
# [*] Epoch: 0230 train_loss= 1.21614 train_rmse= 0.89233 val_loss= 1.39921 val_rmse= 0.90627 		time= 2.85536
# [*] Epoch: 0231 train_loss= 1.25624 train_rmse= 0.90926 val_loss= 1.36454 val_rmse= 0.89780 		time= 2.85796
# [*] Epoch: 0232 train_loss= 1.21762 train_rmse= 0.89367 val_loss= 1.35636 val_rmse= 0.90659 		time= 2.84014
# [*] Epoch: 0233 train_loss= 1.24098 train_rmse= 0.90917 val_loss= 1.37770 val_rmse= 0.91293 		time= 2.80211
# [*] Epoch: 0234 train_loss= 1.28728 train_rmse= 0.95291 val_loss= 1.35491 val_rmse= 0.90318 		time= 2.83921
# [*] Epoch: 0235 train_loss= 1.31404 train_rmse= 0.93398 val_loss= 1.30814 val_rmse= 0.91425 		time= 2.81458
# [*] Epoch: 0236 train_loss= 1.22717 train_rmse= 0.89524 val_loss= 1.36237 val_rmse= 0.95135 		time= 2.78928
# [*] Epoch: 0237 train_loss= 1.24614 train_rmse= 0.91400 val_loss= 1.45081 val_rmse= 0.99264 		time= 2.74582
# [*] Epoch: 0238 train_loss= 1.31409 train_rmse= 0.96348 val_loss= 1.42440 val_rmse= 0.98085 		time= 2.79233
# [*] Epoch: 0239 train_loss= 1.24884 train_rmse= 0.91647 val_loss= 1.44276 val_rmse= 0.97240 		time= 2.76009
# [*] Epoch: 0240 train_loss= 1.26339 train_rmse= 0.93303 val_loss= 1.44360 val_rmse= 0.95452 		time= 2.73155
# [*] Epoch: 0241 train_loss= 1.28057 train_rmse= 0.94993 val_loss= 1.43804 val_rmse= 0.93466 		time= 2.74542
# [*] Epoch: 0242 train_loss= 1.26998 train_rmse= 0.92908 val_loss= 1.38644 val_rmse= 0.92501 		time= 2.73110
# [*] Epoch: 0243 train_loss= 1.25604 train_rmse= 0.92470 val_loss= 1.30814 val_rmse= 0.91729 		time= 2.78656
# [*] Epoch: 0244 train_loss= 1.26333 train_rmse= 0.93168 val_loss= 1.28676 val_rmse= 0.91668 		time= 2.73736
# [*] Epoch: 0245 train_loss= 1.24209 train_rmse= 0.91827 val_loss= 1.29625 val_rmse= 0.92501 		time= 2.74423
# [*] Epoch: 0246 train_loss= 1.23391 train_rmse= 0.91093 val_loss= 1.33474 val_rmse= 0.94346 		time= 2.76933
# [*] Epoch: 0247 train_loss= 1.24443 train_rmse= 0.91033 val_loss= 1.35761 val_rmse= 0.94904 		time= 2.73141
# [*] Epoch: 0248 train_loss= 1.24275 train_rmse= 0.90659 val_loss= 1.36318 val_rmse= 0.93999 		time= 2.74649
# [*] Epoch: 0249 train_loss= 1.23002 train_rmse= 0.90614 val_loss= 1.38159 val_rmse= 0.92929 		time= 2.76336
# [*] Epoch: 0250 train_loss= 1.22955 train_rmse= 0.90580 val_loss= 1.41242 val_rmse= 0.92198 		time= 2.76587
# [*] Epoch: 0251 train_loss= 1.23661 train_rmse= 0.91338 val_loss= 1.42745 val_rmse= 0.91357 		time= 2.75665
# [*] Epoch: 0252 train_loss= 1.24446 train_rmse= 0.90387 val_loss= 1.38012 val_rmse= 0.90908 		time= 2.76068
# [*] Epoch: 0253 train_loss= 1.24562 train_rmse= 0.91765 val_loss= 1.34730 val_rmse= 0.90682 		time= 2.79485
# [*] Epoch: 0254 train_loss= 1.23537 train_rmse= 0.90208 val_loss= 1.29064 val_rmse= 0.90576 		time= 2.81585
# [*] Epoch: 0255 train_loss= 1.25141 train_rmse= 0.92297 val_loss= 1.27493 val_rmse= 0.90884 		time= 2.81893
# [*] Epoch: 0256 train_loss= 1.24059 train_rmse= 0.90928 val_loss= 1.29589 val_rmse= 0.92110 		time= 2.78827
# [*] Epoch: 0257 train_loss= 1.23761 train_rmse= 0.90917 val_loss= 1.30980 val_rmse= 0.93052 		time= 2.72988
# [*] Epoch: 0258 train_loss= 1.22678 train_rmse= 0.90498 val_loss= 1.34553 val_rmse= 0.94344 		time= 2.74187
# [*] Epoch: 0259 train_loss= 1.24501 train_rmse= 0.90006 val_loss= 1.38081 val_rmse= 0.94621 		time= 2.76533
# [*] Epoch: 0260 train_loss= 1.22978 train_rmse= 0.90533 val_loss= 1.37037 val_rmse= 0.92984 		time= 2.73521
# [*] Epoch: 0261 train_loss= 1.23635 train_rmse= 0.91071 val_loss= 1.36521 val_rmse= 0.90647 		time= 2.75795
# [*] Epoch: 0262 train_loss= 1.22603 train_rmse= 0.89990 val_loss= 1.42458 val_rmse= 0.89918 		time= 2.78884
# [*] Epoch: 0263 train_loss= 1.21920 train_rmse= 0.89654 val_loss= 1.50805 val_rmse= 0.90283 		time= 2.76013
# [*] Epoch: 0264 train_loss= 1.28530 train_rmse= 0.90249 val_loss= 1.40411 val_rmse= 0.90634 		time= 2.83044
# [*] Epoch: 0265 train_loss= 1.23835 train_rmse= 0.91115 val_loss= 1.32325 val_rmse= 0.90948 		time= 2.75527
# [*] Epoch: 0266 train_loss= 1.26437 train_rmse= 0.93529 val_loss= 1.28887 val_rmse= 0.91883 		time= 2.80260
# [*] Epoch: 0267 train_loss= 1.28498 train_rmse= 0.94164 val_loss= 1.29128 val_rmse= 0.92292 		time= 2.81599
# [*] Epoch: 0268 train_loss= 1.23145 train_rmse= 0.89948 val_loss= 1.29658 val_rmse= 0.92442 		time= 2.81331
# [*] Epoch: 0269 train_loss= 1.24679 train_rmse= 0.91032 val_loss= 1.34191 val_rmse= 0.93476 		time= 2.76317
# [*] Epoch: 0270 train_loss= 1.22547 train_rmse= 0.89638 val_loss= 1.42880 val_rmse= 0.94906 		time= 2.77794
# [*] Epoch: 0271 train_loss= 1.21998 train_rmse= 0.89735 val_loss= 1.52208 val_rmse= 0.95823 		time= 2.81675
# [*] Epoch: 0272 train_loss= 1.29316 train_rmse= 0.94974 val_loss= 1.50360 val_rmse= 0.93308 		time= 2.75898
# [*] Epoch: 0273 train_loss= 1.24542 train_rmse= 0.90347 val_loss= 1.43354 val_rmse= 0.91606 		time= 2.84496
# [*] Epoch: 0274 train_loss= 1.23231 train_rmse= 0.90482 val_loss= 1.37724 val_rmse= 0.90797 		time= 2.82355
# [*] Epoch: 0275 train_loss= 1.21951 train_rmse= 0.89621 val_loss= 1.36422 val_rmse= 0.90410 		time= 2.77198
# [*] Epoch: 0276 train_loss= 1.23768 train_rmse= 0.90824 val_loss= 1.36320 val_rmse= 0.91458 		time= 2.82458
# [*] Epoch: 0277 train_loss= 1.21719 train_rmse= 0.89497 val_loss= 1.38833 val_rmse= 0.92837 		time= 2.78498
# [*] Epoch: 0278 train_loss= 1.24480 train_rmse= 0.90069 val_loss= 1.43392 val_rmse= 0.93310 		time= 2.77922
# [*] Epoch: 0279 train_loss= 1.21888 train_rmse= 0.89566 val_loss= 1.46202 val_rmse= 0.92398 		time= 2.83134
# [*] Epoch: 0280 train_loss= 1.23534 train_rmse= 0.90667 val_loss= 1.49971 val_rmse= 0.91163 		time= 2.77111
# [*] Epoch: 0281 train_loss= 1.24194 train_rmse= 0.90015 val_loss= 1.46120 val_rmse= 0.90384 		time= 2.75729
# [*] Epoch: 0282 train_loss= 1.21336 train_rmse= 0.89329 val_loss= 1.45235 val_rmse= 0.90374 		time= 2.74118
# [*] Epoch: 0283 train_loss= 1.21607 train_rmse= 0.89249 val_loss= 1.41708 val_rmse= 0.90460 		time= 2.72418
# [*] Epoch: 0284 train_loss= 1.22705 train_rmse= 0.90632 val_loss= 1.42663 val_rmse= 0.91788 		time= 2.76401
# [*] Epoch: 0285 train_loss= 1.21847 train_rmse= 0.89739 val_loss= 1.41710 val_rmse= 0.92307 		time= 2.75193
# [*] Epoch: 0286 train_loss= 1.22270 train_rmse= 0.89949 val_loss= 1.40607 val_rmse= 0.91761 		time= 2.87977
# [*] Epoch: 0287 train_loss= 1.24803 train_rmse= 0.90974 val_loss= 1.33498 val_rmse= 0.90501 		time= 2.71907
# [*] Epoch: 0288 train_loss= 1.21355 train_rmse= 0.89323 val_loss= 1.30723 val_rmse= 0.90889 		time= 2.74541
# [*] Epoch: 0289 train_loss= 1.22863 train_rmse= 0.90091 val_loss= 1.33385 val_rmse= 0.92172 		time= 2.79445
# [*] Epoch: 0290 train_loss= 1.23774 train_rmse= 0.90635 val_loss= 1.34386 val_rmse= 0.91559 		time= 2.82459
# [*] Epoch: 0291 train_loss= 1.21730 train_rmse= 0.89656 val_loss= 1.36681 val_rmse= 0.90588 		time= 2.77384
# [*] Epoch: 0292 train_loss= 1.23934 train_rmse= 0.91490 val_loss= 1.41671 val_rmse= 0.90862 		time= 2.75472
# [*] Epoch: 0293 train_loss= 1.22011 train_rmse= 0.89805 val_loss= 1.45323 val_rmse= 0.91215 		time= 2.72882
# [*] Epoch: 0294 train_loss= 1.24778 train_rmse= 0.90431 val_loss= 1.40449 val_rmse= 0.91653 		time= 2.74256
# [*] Epoch: 0295 train_loss= 1.21215 train_rmse= 0.89354 val_loss= 1.35423 val_rmse= 0.91971 		time= 2.85793
# [*] Epoch: 0296 train_loss= 1.21153 train_rmse= 0.89111 val_loss= 1.34417 val_rmse= 0.92848 		time= 2.74914
# [*] Epoch: 0297 train_loss= 1.20854 train_rmse= 0.88921 val_loss= 1.34549 val_rmse= 0.93780 		time= 2.74743
# [*] Epoch: 0298 train_loss= 1.23469 train_rmse= 0.91066 val_loss= 1.30865 val_rmse= 0.92763 		time= 2.75780
# [*] Epoch: 0299 train_loss= 1.23501 train_rmse= 0.89813 val_loss= 1.28744 val_rmse= 0.91096 		time= 2.78199
# [*] Epoch: 0300 train_loss= 1.21281 train_rmse= 0.89524 val_loss= 1.27002 val_rmse= 0.89728 		time= 2.73966
# [*] Epoch: 0301 train_loss= 1.21971 train_rmse= 0.88823 val_loss= 1.29640 val_rmse= 0.89304 		time= 2.73105
# [*] Epoch: 0302 train_loss= 1.23735 train_rmse= 0.89672 val_loss= 1.38700 val_rmse= 0.89664 		time= 2.73496
# [*] Epoch: 0303 train_loss= 1.22925 train_rmse= 0.90206 val_loss= 1.44948 val_rmse= 0.89870 		time= 2.75702
# [*] Epoch: 0304 train_loss= 1.26946 train_rmse= 0.92191 val_loss= 1.41909 val_rmse= 0.89664 		time= 2.84933
# [*] Epoch: 0305 train_loss= 1.23400 train_rmse= 0.89756 val_loss= 1.34805 val_rmse= 0.90088 		time= 2.82474
# [*] Epoch: 0306 train_loss= 1.22309 train_rmse= 0.90035 val_loss= 1.33339 val_rmse= 0.91605 		time= 2.73045
# [*] Epoch: 0307 train_loss= 1.25034 train_rmse= 0.89830 val_loss= 1.38326 val_rmse= 0.93517 		time= 2.72714
# [*] Epoch: 0308 train_loss= 1.22054 train_rmse= 0.89445 val_loss= 1.43962 val_rmse= 0.94754 		time= 2.73441
# [*] Epoch: 0309 train_loss= 1.22860 train_rmse= 0.89563 val_loss= 1.52194 val_rmse= 0.94999 		time= 2.79495
# [*] Epoch: 0310 train_loss= 1.24463 train_rmse= 0.91749 val_loss= 1.53431 val_rmse= 0.92929 		time= 2.80517
# [*] Epoch: 0311 train_loss= 1.22552 train_rmse= 0.89431 val_loss= 1.48346 val_rmse= 0.91274 		time= 2.78094
# [*] Epoch: 0312 train_loss= 1.21656 train_rmse= 0.89532 val_loss= 1.46652 val_rmse= 0.90482 		time= 2.70667
# [*] Epoch: 0313 train_loss= 1.21323 train_rmse= 0.89092 val_loss= 1.49016 val_rmse= 0.91163 		time= 2.80385
# [*] Epoch: 0314 train_loss= 1.22478 train_rmse= 0.90287 val_loss= 1.50896 val_rmse= 0.91649 		time= 2.76875
# [*] Epoch: 0315 train_loss= 1.23351 train_rmse= 0.90611 val_loss= 1.48361 val_rmse= 0.91608 		time= 2.74091
# [*] Epoch: 0316 train_loss= 1.23439 train_rmse= 0.91109 val_loss= 1.43093 val_rmse= 0.90778 		time= 2.80083
# [*] Epoch: 0317 train_loss= 1.24019 train_rmse= 0.90827 val_loss= 1.37662 val_rmse= 0.90524 		time= 2.83714
# [*] Epoch: 0318 train_loss= 1.21954 train_rmse= 0.89942 val_loss= 1.36627 val_rmse= 0.91271 		time= 2.75280
# [*] Epoch: 0319 train_loss= 1.23407 train_rmse= 0.91132 val_loss= 1.35574 val_rmse= 0.91089 		time= 2.78497
# [*] Epoch: 0320 train_loss= 1.21325 train_rmse= 0.89468 val_loss= 1.34852 val_rmse= 0.91504 		time= 2.84802
# [*] Epoch: 0321 train_loss= 1.23173 train_rmse= 0.90807 val_loss= 1.34176 val_rmse= 0.91418 		time= 2.82825
# [*] Epoch: 0322 train_loss= 1.22830 train_rmse= 0.89787 val_loss= 1.33877 val_rmse= 0.90872 		time= 2.76914
# [*] Epoch: 0323 train_loss= 1.21354 train_rmse= 0.89360 val_loss= 1.37358 val_rmse= 0.91123 		time= 2.77827
# [*] Epoch: 0324 train_loss= 1.21558 train_rmse= 0.89350 val_loss= 1.38565 val_rmse= 0.90829 		time= 2.71928
# [*] Epoch: 0325 train_loss= 1.21573 train_rmse= 0.89402 val_loss= 1.40631 val_rmse= 0.90410 		time= 2.76071
# [*] Epoch: 0326 train_loss= 1.20836 train_rmse= 0.88702 val_loss= 1.41122 val_rmse= 0.90313 		time= 2.80332
# [*] Epoch: 0327 train_loss= 1.23984 train_rmse= 0.91549 val_loss= 1.41499 val_rmse= 0.90586 		time= 2.72197
# [*] Epoch: 0328 train_loss= 1.21807 train_rmse= 0.89168 val_loss= 1.38070 val_rmse= 0.90599 		time= 2.79286
# [*] Epoch: 0329 train_loss= 1.20415 train_rmse= 0.88607 val_loss= 1.33923 val_rmse= 0.90697 		time= 2.73630
# [*] Epoch: 0330 train_loss= 1.20295 train_rmse= 0.88249 val_loss= 1.31607 val_rmse= 0.90589 		time= 2.73233
# [*] Epoch: 0331 train_loss= 1.21110 train_rmse= 0.89377 val_loss= 1.28898 val_rmse= 0.90414 		time= 2.74812
# [*] Epoch: 0332 train_loss= 1.21139 train_rmse= 0.89046 val_loss= 1.27547 val_rmse= 0.90362 		time= 2.69861
# [*] Epoch: 0333 train_loss= 1.21519 train_rmse= 0.89354 val_loss= 1.27458 val_rmse= 0.90410 		time= 2.78003
# [*] Epoch: 0334 train_loss= 1.20209 train_rmse= 0.88498 val_loss= 1.28153 val_rmse= 0.90374 		time= 2.73318
# [*] Epoch: 0335 train_loss= 1.26259 train_rmse= 0.91212 val_loss= 1.32326 val_rmse= 0.89910 		time= 2.75362
# [*] Epoch: 0336 train_loss= 1.22307 train_rmse= 0.90307 val_loss= 1.36613 val_rmse= 0.89350 		time= 2.78240
# [*] Epoch: 0337 train_loss= 1.20741 train_rmse= 0.88812 val_loss= 1.40060 val_rmse= 0.89419 		time= 2.79203
# [*] Epoch: 0338 train_loss= 1.21666 train_rmse= 0.89578 val_loss= 1.43849 val_rmse= 0.89618 		time= 2.74957
# [*] Epoch: 0339 train_loss= 1.20253 train_rmse= 0.88331 val_loss= 1.51316 val_rmse= 0.90230 		time= 2.72944
# [*] Epoch: 0340 train_loss= 1.21863 train_rmse= 0.89670 val_loss= 1.57774 val_rmse= 0.91084 		time= 2.73642
# [*] Epoch: 0341 train_loss= 1.21627 train_rmse= 0.88959 val_loss= 1.65449 val_rmse= 0.91234 		time= 2.75097
# [*] Epoch: 0342 train_loss= 1.22713 train_rmse= 0.88781 val_loss= 1.61568 val_rmse= 0.91486 		time= 2.82775
# [*] Epoch: 0343 train_loss= 1.24748 train_rmse= 0.91624 val_loss= 1.50913 val_rmse= 0.90281 		time= 2.77924
# [*] Epoch: 0344 train_loss= 1.20614 train_rmse= 0.88885 val_loss= 1.43565 val_rmse= 0.89709 		time= 2.74182
# [*] Epoch: 0345 train_loss= 1.21206 train_rmse= 0.88748 val_loss= 1.41789 val_rmse= 0.89300 		time= 2.74862
# [*] Epoch: 0346 train_loss= 1.21291 train_rmse= 0.88453 val_loss= 1.43910 val_rmse= 0.89226 		time= 2.79470
# [*] Epoch: 0347 train_loss= 1.23362 train_rmse= 0.89773 val_loss= 1.41117 val_rmse= 0.89193 		time= 2.75824
# [*] Epoch: 0348 train_loss= 1.21340 train_rmse= 0.88895 val_loss= 1.36071 val_rmse= 0.89264 		time= 2.72594
# [*] Epoch: 0349 train_loss= 1.20749 train_rmse= 0.88878 val_loss= 1.31990 val_rmse= 0.89212 		time= 2.73879
# [*] Epoch: 0350 train_loss= 1.21021 train_rmse= 0.89085 val_loss= 1.29102 val_rmse= 0.89587 		time= 2.77581
# [*] Epoch: 0351 train_loss= 1.21417 train_rmse= 0.88708 val_loss= 1.30111 val_rmse= 0.90268 		time= 2.75096
# [*] Epoch: 0352 train_loss= 1.20581 train_rmse= 0.88588 val_loss= 1.33101 val_rmse= 0.91126 		time= 2.74312
# [*] Epoch: 0353 train_loss= 1.21917 train_rmse= 0.89518 val_loss= 1.37863 val_rmse= 0.91777 		time= 2.78617
# [*] Epoch: 0354 train_loss= 1.20060 train_rmse= 0.88338 val_loss= 1.41720 val_rmse= 0.91915 		time= 2.75180
# [*] Epoch: 0355 train_loss= 1.22745 train_rmse= 0.89827 val_loss= 1.51561 val_rmse= 0.92193 		time= 2.78880
# [*] Epoch: 0356 train_loss= 1.22079 train_rmse= 0.89271 val_loss= 1.54224 val_rmse= 0.91446 		time= 2.78093
# [*] Epoch: 0357 train_loss= 1.20550 train_rmse= 0.88682 val_loss= 1.56423 val_rmse= 0.90336 		time= 2.74583
# [*] Epoch: 0358 train_loss= 1.23724 train_rmse= 0.89684 val_loss= 1.50603 val_rmse= 0.89363 		time= 2.80072
# [*] Epoch: 0359 train_loss= 1.20797 train_rmse= 0.88990 val_loss= 1.44082 val_rmse= 0.89024 		time= 2.74041
# [*] Epoch: 0360 train_loss= 1.24799 train_rmse= 0.89396 val_loss= 1.32050 val_rmse= 0.89286 		time= 2.75613
# [*] Epoch: 0361 train_loss= 1.20884 train_rmse= 0.88754 val_loss= 1.28299 val_rmse= 0.89793 		time= 2.76392
# [*] Epoch: 0362 train_loss= 1.22029 train_rmse= 0.89222 val_loss= 1.27547 val_rmse= 0.90196 		time= 2.77871
# [*] Epoch: 0363 train_loss= 1.20845 train_rmse= 0.88814 val_loss= 1.28423 val_rmse= 0.90582 		time= 2.76177
# [*] Epoch: 0364 train_loss= 1.22855 train_rmse= 0.89280 val_loss= 1.29765 val_rmse= 0.90370 		time= 2.74746
# [*] Epoch: 0365 train_loss= 1.23652 train_rmse= 0.90307 val_loss= 1.32361 val_rmse= 0.89504 		time= 2.74823
# [*] Epoch: 0366 train_loss= 1.21165 train_rmse= 0.88222 val_loss= 1.32550 val_rmse= 0.89359 		time= 2.76150
# [*] Epoch: 0367 train_loss= 1.21395 train_rmse= 0.88415 val_loss= 1.29275 val_rmse= 0.89322 		time= 2.76748
# [*] Epoch: 0368 train_loss= 1.20381 train_rmse= 0.88592 val_loss= 1.27647 val_rmse= 0.89394 		time= 2.77056
# [*] Epoch: 0369 train_loss= 1.21167 train_rmse= 0.88584 val_loss= 1.28313 val_rmse= 0.89663 		time= 2.74879
# [*] Epoch: 0370 train_loss= 1.22306 train_rmse= 0.88732 val_loss= 1.30080 val_rmse= 0.89503 		time= 2.81598
# [*] Epoch: 0371 train_loss= 1.20521 train_rmse= 0.88875 val_loss= 1.34091 val_rmse= 0.89668 		time= 2.78016
# [*] Epoch: 0372 train_loss= 1.21043 train_rmse= 0.89129 val_loss= 1.38697 val_rmse= 0.89582 		time= 2.74956
# [*] Epoch: 0373 train_loss= 1.22320 train_rmse= 0.89510 val_loss= 1.38722 val_rmse= 0.89519 		time= 2.76684
# [*] Epoch: 0374 train_loss= 1.20895 train_rmse= 0.89037 val_loss= 1.40478 val_rmse= 0.89679 		time= 2.76836
# [*] Epoch: 0375 train_loss= 1.20145 train_rmse= 0.88475 val_loss= 1.43625 val_rmse= 0.89734 		time= 2.75052
# [*] Epoch: 0376 train_loss= 1.21927 train_rmse= 0.90064 val_loss= 1.47147 val_rmse= 0.89813 		time= 2.76662
# [*] Epoch: 0377 train_loss= 1.26047 train_rmse= 0.89247 val_loss= 1.38744 val_rmse= 0.90173 		time= 2.72398
# [*] Epoch: 0378 train_loss= 1.23596 train_rmse= 0.90933 val_loss= 1.34858 val_rmse= 0.90281 		time= 2.74289
# [*] Epoch: 0379 train_loss= 1.23942 train_rmse= 0.91337 val_loss= 1.32639 val_rmse= 0.89687 		time= 2.75645
# [*] Epoch: 0380 train_loss= 1.23819 train_rmse= 0.91834 val_loss= 1.32270 val_rmse= 0.89135 		time= 2.78144
# [*] Epoch: 0381 train_loss= 1.20258 train_rmse= 0.88718 val_loss= 1.35332 val_rmse= 0.89908 		time= 2.74025
# [*] Epoch: 0382 train_loss= 1.20666 train_rmse= 0.89012 val_loss= 1.38286 val_rmse= 0.91153 		time= 2.76677
# [*] Epoch: 0383 train_loss= 1.21746 train_rmse= 0.89654 val_loss= 1.38654 val_rmse= 0.91349 		time= 2.82814
# [*] Epoch: 0384 train_loss= 1.20294 train_rmse= 0.88620 val_loss= 1.37804 val_rmse= 0.91107 		time= 2.72657
# [*] Epoch: 0385 train_loss= 1.22718 train_rmse= 0.90010 val_loss= 1.33530 val_rmse= 0.90572 		time= 2.79959
# [*] Epoch: 0386 train_loss= 1.20459 train_rmse= 0.88650 val_loss= 1.29437 val_rmse= 0.90481 		time= 2.80174
# [*] Epoch: 0387 train_loss= 1.24817 train_rmse= 0.90539 val_loss= 1.29558 val_rmse= 0.90543 		time= 2.73010
# [*] Epoch: 0388 train_loss= 1.20153 train_rmse= 0.88326 val_loss= 1.30453 val_rmse= 0.90315 		time= 2.74356
# [*] Epoch: 0389 train_loss= 1.20735 train_rmse= 0.88417 val_loss= 1.34753 val_rmse= 0.90454 		time= 2.74563
# [*] Epoch: 0390 train_loss= 1.20368 train_rmse= 0.88402 val_loss= 1.38804 val_rmse= 0.90086 		time= 2.79296
# [*] Epoch: 0391 train_loss= 1.22512 train_rmse= 0.90224 val_loss= 1.41559 val_rmse= 0.89564 		time= 2.77468
# [*] Epoch: 0392 train_loss= 1.20352 train_rmse= 0.88419 val_loss= 1.42439 val_rmse= 0.89376 		time= 2.75564
# [*] Epoch: 0393 train_loss= 1.21010 train_rmse= 0.89125 val_loss= 1.43057 val_rmse= 0.89377 		time= 2.75046
# [*] Epoch: 0394 train_loss= 1.20522 train_rmse= 0.88618 val_loss= 1.40086 val_rmse= 0.89512 		time= 2.76761
# [*] Epoch: 0395 train_loss= 1.20412 train_rmse= 0.88619 val_loss= 1.39782 val_rmse= 0.89660 		time= 2.73427
# [*] Epoch: 0396 train_loss= 1.20581 train_rmse= 0.88715 val_loss= 1.40645 val_rmse= 0.90200 		time= 2.81006
# [*] Epoch: 0397 train_loss= 1.19757 train_rmse= 0.88129 val_loss= 1.41085 val_rmse= 0.90659 		time= 2.78844
# [*] Epoch: 0398 train_loss= 1.21233 train_rmse= 0.89265 val_loss= 1.39093 val_rmse= 0.90732 		time= 2.76319
# [*] Epoch: 0399 train_loss= 1.19984 train_rmse= 0.88463 val_loss= 1.39486 val_rmse= 0.91817 		time= 2.73192
# [*] Epoch: 0400 train_loss= 1.21530 train_rmse= 0.89602 val_loss= 1.37678 val_rmse= 0.91383 		time= 2.76547
# [*] Epoch: 0401 train_loss= 1.20570 train_rmse= 0.88792 val_loss= 1.34542 val_rmse= 0.90443 		time= 2.72526
# [*] Epoch: 0402 train_loss= 1.19662 train_rmse= 0.88175 val_loss= 1.33568 val_rmse= 0.90012 		time= 2.75725
# [*] Epoch: 0403 train_loss= 1.22933 train_rmse= 0.91370 val_loss= 1.32865 val_rmse= 0.89768 		time= 2.73030
# [*] Epoch: 0404 train_loss= 1.20193 train_rmse= 0.88536 val_loss= 1.32294 val_rmse= 0.89458 		time= 2.74974
# [*] Epoch: 0405 train_loss= 1.20496 train_rmse= 0.89036 val_loss= 1.32466 val_rmse= 0.89519 		time= 2.76143
# [*] Epoch: 0406 train_loss= 1.21397 train_rmse= 0.88100 val_loss= 1.38088 val_rmse= 0.89661 		time= 2.80632
# [*] Epoch: 0407 train_loss= 1.21831 train_rmse= 0.89926 val_loss= 1.43486 val_rmse= 0.90109 		time= 2.75553
# [*] Epoch: 0408 train_loss= 1.21071 train_rmse= 0.89297 val_loss= 1.47331 val_rmse= 0.90423 		time= 2.77218
# [*] Epoch: 0409 train_loss= 1.21651 train_rmse= 0.89237 val_loss= 1.44138 val_rmse= 0.90318 		time= 2.76885
# [*] Epoch: 0410 train_loss= 1.21786 train_rmse= 0.88900 val_loss= 1.37284 val_rmse= 0.90676 		time= 2.73172
# [*] Epoch: 0411 train_loss= 1.19690 train_rmse= 0.88116 val_loss= 1.32454 val_rmse= 0.91315 		time= 2.74334
# [*] Epoch: 0412 train_loss= 1.20810 train_rmse= 0.88461 val_loss= 1.31616 val_rmse= 0.92027 		time= 2.73952
# [*] Epoch: 0413 train_loss= 1.24005 train_rmse= 0.88616 val_loss= 1.34072 val_rmse= 0.92438 		time= 2.73294
# [*] Epoch: 0414 train_loss= 1.20894 train_rmse= 0.88104 val_loss= 1.38041 val_rmse= 0.92355 		time= 2.73532
# [*] Epoch: 0415 train_loss= 1.20947 train_rmse= 0.88559 val_loss= 1.45198 val_rmse= 0.91788 		time= 2.75296
# [*] Epoch: 0416 train_loss= 1.19371 train_rmse= 0.88013 val_loss= 1.51894 val_rmse= 0.91332 		time= 2.81563
# [*] Epoch: 0417 train_loss= 1.21824 train_rmse= 0.90118 val_loss= 1.57293 val_rmse= 0.91037 		time= 2.71207
# [*] Epoch: 0418 train_loss= 1.23303 train_rmse= 0.88833 val_loss= 1.50476 val_rmse= 0.90432 		time= 2.84252
# [*] Epoch: 0419 train_loss= 1.22894 train_rmse= 0.90421 val_loss= 1.39665 val_rmse= 0.89259 		time= 2.71953
# [*] Epoch: 0420 train_loss= 1.19726 train_rmse= 0.88037 val_loss= 1.36297 val_rmse= 0.89389 		time= 2.75975
# [*] Epoch: 0421 train_loss= 1.20107 train_rmse= 0.88468 val_loss= 1.36094 val_rmse= 0.90688 		time= 2.74814
# [*] Epoch: 0422 train_loss= 1.20594 train_rmse= 0.88824 val_loss= 1.36385 val_rmse= 0.91941 		time= 2.80003
# [*] Epoch: 0423 train_loss= 1.30858 train_rmse= 0.97230 val_loss= 1.33388 val_rmse= 0.90389 		time= 2.76604
# [*] Epoch: 0424 train_loss= 1.20618 train_rmse= 0.88793 val_loss= 1.31356 val_rmse= 0.89362 		time= 2.76025
# [*] Epoch: 0425 train_loss= 1.24544 train_rmse= 0.91668 val_loss= 1.35474 val_rmse= 0.89538 		time= 2.74184
# [*] Epoch: 0426 train_loss= 1.19412 train_rmse= 0.88080 val_loss= 1.41621 val_rmse= 0.91022 		time= 2.75948
# [*] Epoch: 0427 train_loss= 1.20881 train_rmse= 0.89381 val_loss= 1.48105 val_rmse= 0.92158 		time= 2.75890
# [*] Epoch: 0428 train_loss= 1.22177 train_rmse= 0.89890 val_loss= 1.48389 val_rmse= 0.92543 		time= 2.75789
# [*] Epoch: 0429 train_loss= 1.23300 train_rmse= 0.89947 val_loss= 1.42248 val_rmse= 0.92343 		time= 2.80032
# [*] Epoch: 0430 train_loss= 1.21362 train_rmse= 0.89229 val_loss= 1.34373 val_rmse= 0.91874 		time= 2.79652
# [*] Epoch: 0431 train_loss= 1.22297 train_rmse= 0.88927 val_loss= 1.31978 val_rmse= 0.91452 		time= 2.76696
# [*] Epoch: 0432 train_loss= 1.19804 train_rmse= 0.88363 val_loss= 1.30467 val_rmse= 0.91173 		time= 2.74242
# [*] Epoch: 0433 train_loss= 1.22680 train_rmse= 0.88880 val_loss= 1.30821 val_rmse= 0.90467 		time= 2.75443
# [*] Epoch: 0434 train_loss= 1.20150 train_rmse= 0.88267 val_loss= 1.33071 val_rmse= 0.89908 		time= 2.78009
# [*] Epoch: 0435 train_loss= 1.21666 train_rmse= 0.89327 val_loss= 1.39057 val_rmse= 0.89731 		time= 2.84496
# [*] Epoch: 0436 train_loss= 1.20028 train_rmse= 0.88408 val_loss= 1.45039 val_rmse= 0.89391 		time= 2.76047
# [*] Epoch: 0437 train_loss= 1.20148 train_rmse= 0.88358 val_loss= 1.47629 val_rmse= 0.89378 		time= 2.75395
# [*] Epoch: 0438 train_loss= 1.19799 train_rmse= 0.88258 val_loss= 1.51718 val_rmse= 0.89487 		time= 2.76962
# [*] Epoch: 0439 train_loss= 1.23824 train_rmse= 0.89062 val_loss= 1.45336 val_rmse= 0.90000 		time= 2.73913
# [*] Epoch: 0440 train_loss= 1.26310 train_rmse= 0.89108 val_loss= 1.34490 val_rmse= 0.91091 		time= 2.72203
# [*] Epoch: 0441 train_loss= 1.21030 train_rmse= 0.88013 val_loss= 1.31032 val_rmse= 0.91906 		time= 2.71940
# [*] Epoch: 0442 train_loss= 1.22029 train_rmse= 0.88727 val_loss= 1.29127 val_rmse= 0.91617 		time= 2.74277
# [*] Epoch: 0443 train_loss= 1.25737 train_rmse= 0.89062 val_loss= 1.29072 val_rmse= 0.90896 		time= 2.73175
# [*] Epoch: 0444 train_loss= 1.22900 train_rmse= 0.89052 val_loss= 1.30186 val_rmse= 0.89794 		time= 2.73479
# ...
# [*] Epoch: 3353 train_loss= 1.13118 train_rmse= 0.83220 val_loss= 1.40051 val_rmse= 0.88989 		time= 2.78848
# [*] Epoch: 3354 train_loss= 1.13796 train_rmse= 0.83519 val_loss= 1.37675 val_rmse= 0.89398 		time= 2.70064
# [*] Epoch: 3355 train_loss= 1.13201 train_rmse= 0.83328 val_loss= 1.37409 val_rmse= 0.89560 		time= 2.73033
# [*] Epoch: 3356 train_loss= 1.13000 train_rmse= 0.83097 val_loss= 1.37383 val_rmse= 0.89815 		time= 2.87647
# [*] Epoch: 3357 train_loss= 1.13844 train_rmse= 0.83287 val_loss= 1.38947 val_rmse= 0.89717 		time= 2.72050
# [*] Epoch: 3358 train_loss= 1.13767 train_rmse= 0.83402 val_loss= 1.41634 val_rmse= 0.89468 		time= 2.79896
# [*] Epoch: 3359 train_loss= 1.13447 train_rmse= 0.83392 val_loss= 1.44119 val_rmse= 0.88733 		time= 2.70107
# [*] Epoch: 3360 train_loss= 1.14733 train_rmse= 0.83823 val_loss= 1.42687 val_rmse= 0.89020 		time= 2.80998
# [*] Epoch: 3361 train_loss= 1.13903 train_rmse= 0.83813 val_loss= 1.40073 val_rmse= 0.88508 		time= 2.73891
# [*] Epoch: 3362 train_loss= 1.13950 train_rmse= 0.83679 val_loss= 1.37401 val_rmse= 0.88933 		time= 2.81515
# [*] Epoch: 3363 train_loss= 1.13665 train_rmse= 0.83513 val_loss= 1.35482 val_rmse= 0.89856 		time= 2.73339
# [*] Epoch: 3364 train_loss= 1.16584 train_rmse= 0.85013 val_loss= 1.35445 val_rmse= 0.89757 		time= 2.74136
# [*] Epoch: 3365 train_loss= 1.14211 train_rmse= 0.83925 val_loss= 1.35517 val_rmse= 0.89116 		time= 2.73140
# [*] Epoch: 3366 train_loss= 1.14286 train_rmse= 0.83793 val_loss= 1.38319 val_rmse= 0.88770 		time= 2.79745
# [*] Epoch: 3367 train_loss= 1.13484 train_rmse= 0.83167 val_loss= 1.45114 val_rmse= 0.88530 		time= 2.76682
# [*] Epoch: 3368 train_loss= 1.13921 train_rmse= 0.83697 val_loss= 1.49381 val_rmse= 0.88809 		time= 2.71715
# [*] Epoch: 3369 train_loss= 1.14173 train_rmse= 0.83919 val_loss= 1.49165 val_rmse= 0.88653 		time= 2.73593
# [*] Epoch: 3370 train_loss= 1.13830 train_rmse= 0.83232 val_loss= 1.44439 val_rmse= 0.88617 		time= 2.73086
# [*] Epoch: 3371 train_loss= 1.13573 train_rmse= 0.83627 val_loss= 1.41448 val_rmse= 0.88711 		time= 2.73572
# [*] Epoch: 3372 train_loss= 1.13420 train_rmse= 0.83390 val_loss= 1.40017 val_rmse= 0.88581 		time= 2.75134
# [*] Epoch: 3373 train_loss= 1.13211 train_rmse= 0.83283 val_loss= 1.39219 val_rmse= 0.88768 		time= 2.73131
# [*] Epoch: 3374 train_loss= 1.12939 train_rmse= 0.83065 val_loss= 1.41282 val_rmse= 0.89156 		time= 2.70715
# [*] Epoch: 3375 train_loss= 1.13177 train_rmse= 0.83235 val_loss= 1.40074 val_rmse= 0.88755 		time= 2.71491
# [*] Epoch: 3376 train_loss= 1.13070 train_rmse= 0.83160 val_loss= 1.41180 val_rmse= 0.88832 		time= 2.73538
# [*] Epoch: 3377 train_loss= 1.13065 train_rmse= 0.83146 val_loss= 1.41297 val_rmse= 0.88618 		time= 2.69731
# [*] Epoch: 3378 train_loss= 1.12896 train_rmse= 0.82968 val_loss= 1.42893 val_rmse= 0.88845 		time= 2.73089
# [*] Epoch: 3379 train_loss= 1.12799 train_rmse= 0.83036 val_loss= 1.42811 val_rmse= 0.88787 		time= 2.71362
# [*] Epoch: 3380 train_loss= 1.14592 train_rmse= 0.83410 val_loss= 1.40091 val_rmse= 0.89260 		time= 2.76137
# [*] Epoch: 3381 train_loss= 1.13008 train_rmse= 0.83131 val_loss= 1.37084 val_rmse= 0.89277 		time= 2.72966
# [*] Epoch: 3382 train_loss= 1.13190 train_rmse= 0.83213 val_loss= 1.35271 val_rmse= 0.89183 		time= 2.76255
# [*] Epoch: 3383 train_loss= 1.13192 train_rmse= 0.83264 val_loss= 1.33605 val_rmse= 0.88793 		time= 2.72698
# [*] Epoch: 3384 train_loss= 1.13516 train_rmse= 0.82937 val_loss= 1.31841 val_rmse= 0.89448 		time= 2.73331
# [*] Epoch: 3385 train_loss= 1.15337 train_rmse= 0.83282 val_loss= 1.31305 val_rmse= 0.89024 		time= 2.72276
# [*] Epoch: 3386 train_loss= 1.14494 train_rmse= 0.83037 val_loss= 1.32965 val_rmse= 0.87976 		time= 2.70250
# [*] Epoch: 3387 train_loss= 1.13095 train_rmse= 0.83158 val_loss= 1.36208 val_rmse= 0.87529 		time= 2.75008
# [*] Epoch: 3388 train_loss= 1.12845 train_rmse= 0.82911 val_loss= 1.41263 val_rmse= 0.87247 		time= 2.69120
# [*] Epoch: 3389 train_loss= 1.13264 train_rmse= 0.83261 val_loss= 1.45581 val_rmse= 0.87391 		time= 2.70464
# [*] Epoch: 3390 train_loss= 1.14196 train_rmse= 0.83339 val_loss= 1.43636 val_rmse= 0.87940 		time= 2.71617
# [*] Epoch: 3391 train_loss= 1.13559 train_rmse= 0.83326 val_loss= 1.40691 val_rmse= 0.88532 		time= 2.75561
# [*] Epoch: 3392 train_loss= 1.12708 train_rmse= 0.82901 val_loss= 1.40070 val_rmse= 0.89545 		time= 2.76629
# [*] Epoch: 3393 train_loss= 1.13733 train_rmse= 0.83475 val_loss= 1.39320 val_rmse= 0.89897 		time= 2.77085
# [*] Epoch: 3394 train_loss= 1.13066 train_rmse= 0.83059 val_loss= 1.36501 val_rmse= 0.89804 		time= 2.72459
# [*] Epoch: 3395 train_loss= 1.13733 train_rmse= 0.83186 val_loss= 1.36035 val_rmse= 0.88961 		time= 2.72839
# [*] Epoch: 3396 train_loss= 1.13079 train_rmse= 0.83042 val_loss= 1.38254 val_rmse= 0.88572 		time= 2.68849
# [*] Epoch: 3397 train_loss= 1.13313 train_rmse= 0.83240 val_loss= 1.42683 val_rmse= 0.87807 		time= 2.72366
# [*] Epoch: 3398 train_loss= 1.14218 train_rmse= 0.83779 val_loss= 1.43697 val_rmse= 0.87748 		time= 2.75879
# [*] Epoch: 3399 train_loss= 1.13507 train_rmse= 0.83301 val_loss= 1.45379 val_rmse= 0.88348 		time= 2.75812
# [*] Epoch: 3400 train_loss= 1.14561 train_rmse= 0.83835 val_loss= 1.42257 val_rmse= 0.89270 		time= 2.74028
# [*] Epoch: 3401 train_loss= 1.13178 train_rmse= 0.83113 val_loss= 1.39203 val_rmse= 0.90427 		time= 2.73846
# [*] Epoch: 3402 train_loss= 1.14375 train_rmse= 0.83985 val_loss= 1.33990 val_rmse= 0.90475 		time= 2.75436
# [*] Epoch: 3403 train_loss= 1.15404 train_rmse= 0.83801 val_loss= 1.32740 val_rmse= 0.90519 		time= 2.74112
# [*] Epoch: 3404 train_loss= 1.14742 train_rmse= 0.83539 val_loss= 1.33314 val_rmse= 0.89876 		time= 2.80589
# [*] Epoch: 3405 train_loss= 1.14003 train_rmse= 0.83034 val_loss= 1.36303 val_rmse= 0.89459 		time= 2.73486
# [*] Epoch: 3406 train_loss= 1.12883 train_rmse= 0.82794 val_loss= 1.40447 val_rmse= 0.88550 		time= 2.79041
# [*] Epoch: 3407 train_loss= 1.13389 train_rmse= 0.83276 val_loss= 1.47721 val_rmse= 0.88070 		time= 2.70256
# [*] Epoch: 3408 train_loss= 1.13843 train_rmse= 0.83482 val_loss= 1.54445 val_rmse= 0.88206 		time= 2.73022
# [*] Epoch: 3409 train_loss= 1.14119 train_rmse= 0.83319 val_loss= 1.54229 val_rmse= 0.87784 		time= 2.79279
# [*] Epoch: 3410 train_loss= 1.15785 train_rmse= 0.83655 val_loss= 1.45473 val_rmse= 0.88586 		time= 2.76007
# [*] Epoch: 3411 train_loss= 1.12862 train_rmse= 0.82993 val_loss= 1.40363 val_rmse= 0.89306 		time= 2.77379
# [*] Epoch: 3412 train_loss= 1.13021 train_rmse= 0.82979 val_loss= 1.36984 val_rmse= 0.89863 		time= 2.70800
# [*] Epoch: 3413 train_loss= 1.12742 train_rmse= 0.82963 val_loss= 1.34862 val_rmse= 0.89900 		time= 2.68028
# [*] Epoch: 3414 train_loss= 1.14134 train_rmse= 0.83430 val_loss= 1.34136 val_rmse= 0.89690 		time= 2.71824
# [*] Epoch: 3415 train_loss= 1.14101 train_rmse= 0.83239 val_loss= 1.35327 val_rmse= 0.88916 		time= 2.68999
# [*] Epoch: 3416 train_loss= 1.13018 train_rmse= 0.83054 val_loss= 1.38212 val_rmse= 0.88401 		time= 2.71605
# [*] Epoch: 3417 train_loss= 1.13160 train_rmse= 0.83178 val_loss= 1.41005 val_rmse= 0.88179 		time= 2.74418
# [*] Epoch: 3418 train_loss= 1.14559 train_rmse= 0.83140 val_loss= 1.38225 val_rmse= 0.88228 		time= 2.73690
# [*] Epoch: 3419 train_loss= 1.13399 train_rmse= 0.83278 val_loss= 1.37067 val_rmse= 0.88376 		time= 2.73627
# [*] Epoch: 3420 train_loss= 1.12917 train_rmse= 0.83039 val_loss= 1.36421 val_rmse= 0.88722 		time= 2.77191
# [*] Epoch: 3421 train_loss= 1.12776 train_rmse= 0.82903 val_loss= 1.37178 val_rmse= 0.88878 		time= 2.74994
# [*] Epoch: 3422 train_loss= 1.13019 train_rmse= 0.83195 val_loss= 1.39324 val_rmse= 0.89374 		time= 2.83206
# [*] Epoch: 3423 train_loss= 1.13634 train_rmse= 0.83514 val_loss= 1.39704 val_rmse= 0.89264 		time= 2.71585
# [*] Epoch: 3424 train_loss= 1.13270 train_rmse= 0.83065 val_loss= 1.40161 val_rmse= 0.88655 		time= 2.75908
# [*] Epoch: 3425 train_loss= 1.13074 train_rmse= 0.83045 val_loss= 1.43449 val_rmse= 0.88190 		time= 2.70313
# [*] Epoch: 3426 train_loss= 1.13187 train_rmse= 0.83117 val_loss= 1.45377 val_rmse= 0.87957 		time= 2.69381
# [*] Epoch: 3427 train_loss= 1.13098 train_rmse= 0.82966 val_loss= 1.44791 val_rmse= 0.88195 		time= 2.73290
# [*] Epoch: 3428 train_loss= 1.13424 train_rmse= 0.83041 val_loss= 1.41930 val_rmse= 0.88899 		time= 2.75657
# [*] Epoch: 3429 train_loss= 1.13037 train_rmse= 0.83124 val_loss= 1.38629 val_rmse= 0.89248 		time= 2.72232
# [*] Epoch: 3430 train_loss= 1.12670 train_rmse= 0.82864 val_loss= 1.37998 val_rmse= 0.89964 		time= 2.73619
# [*] Epoch: 3431 train_loss= 1.13306 train_rmse= 0.83022 val_loss= 1.37502 val_rmse= 0.89869 		time= 2.75556
# [*] Epoch: 3432 train_loss= 1.14094 train_rmse= 0.83223 val_loss= 1.37265 val_rmse= 0.88753 		time= 2.70053
# [*] Epoch: 3433 train_loss= 1.13605 train_rmse= 0.83302 val_loss= 1.39421 val_rmse= 0.87870 		time= 2.70912
# [*] Epoch: 3434 train_loss= 1.12622 train_rmse= 0.82650 val_loss= 1.43956 val_rmse= 0.87144 		time= 2.72829
# [*] Epoch: 3435 train_loss= 1.14702 train_rmse= 0.83661 val_loss= 1.42267 val_rmse= 0.87389 		time= 2.70016
# [*] Epoch: 3436 train_loss= 1.13995 train_rmse= 0.83277 val_loss= 1.38417 val_rmse= 0.87984 		time= 2.70461
# [*] Epoch: 3437 train_loss= 1.13164 train_rmse= 0.83235 val_loss= 1.35184 val_rmse= 0.88813 		time= 2.77542
# [*] Epoch: 3438 train_loss= 1.13022 train_rmse= 0.82987 val_loss= 1.33782 val_rmse= 0.89150 		time= 2.72299
# [*] Epoch: 3439 train_loss= 1.13761 train_rmse= 0.83165 val_loss= 1.33732 val_rmse= 0.89432 		time= 2.69044
# [*] Epoch: 3440 train_loss= 1.13509 train_rmse= 0.82995 val_loss= 1.35571 val_rmse= 0.89519 		time= 2.76619
# [*] Epoch: 3441 train_loss= 1.13562 train_rmse= 0.83226 val_loss= 1.39093 val_rmse= 0.88915 		time= 2.91209
# [*] Epoch: 3442 train_loss= 1.13086 train_rmse= 0.83124 val_loss= 1.44045 val_rmse= 0.88604 		time= 2.81195
# [*] Epoch: 3443 train_loss= 1.14709 train_rmse= 0.83094 val_loss= 1.44495 val_rmse= 0.88685 		time= 2.84967
# [*] Epoch: 3444 train_loss= 1.12712 train_rmse= 0.82887 val_loss= 1.45618 val_rmse= 0.88933 		time= 2.76182
# [*] Epoch: 3445 train_loss= 1.13172 train_rmse= 0.83304 val_loss= 1.45830 val_rmse= 0.88888 		time= 2.75371
# [*] Epoch: 3446 train_loss= 1.13506 train_rmse= 0.83360 val_loss= 1.43639 val_rmse= 0.88455 		time= 2.79978
# [*] Epoch: 3447 train_loss= 1.12741 train_rmse= 0.82927 val_loss= 1.42003 val_rmse= 0.88758 		time= 2.78113
# [*] Epoch: 3448 train_loss= 1.13026 train_rmse= 0.83180 val_loss= 1.41107 val_rmse= 0.88450 		time= 2.82801
# [*] Epoch: 3449 train_loss= 1.13092 train_rmse= 0.83137 val_loss= 1.40207 val_rmse= 0.88824 		time= 2.75610
# [*] Epoch: 3450 train_loss= 1.12849 train_rmse= 0.82980 val_loss= 1.39410 val_rmse= 0.88771 		time= 2.77565
# [*] Epoch: 3451 train_loss= 1.13146 train_rmse= 0.83202 val_loss= 1.39096 val_rmse= 0.88735 		time= 2.77974
# [*] Epoch: 3452 train_loss= 1.12744 train_rmse= 0.82900 val_loss= 1.37904 val_rmse= 0.88446 		time= 2.77527
# [*] Epoch: 3453 train_loss= 1.12833 train_rmse= 0.82963 val_loss= 1.37841 val_rmse= 0.88257 		time= 2.76549
# [*] Epoch: 3454 train_loss= 1.13413 train_rmse= 0.82903 val_loss= 1.39865 val_rmse= 0.88372 		time= 2.80851
# [*] Epoch: 3455 train_loss= 1.13182 train_rmse= 0.83251 val_loss= 1.41060 val_rmse= 0.88001 		time= 2.77917
# [*] Epoch: 3456 train_loss= 1.12896 train_rmse= 0.82946 val_loss= 1.39828 val_rmse= 0.88250 		time= 2.77552
# [*] Epoch: 3457 train_loss= 1.12984 train_rmse= 0.83086 val_loss= 1.41190 val_rmse= 0.88345 		time= 2.73995
# [*] Epoch: 3458 train_loss= 1.12734 train_rmse= 0.82898 val_loss= 1.40203 val_rmse= 0.88666 		time= 2.74577
# [*] Epoch: 3459 train_loss= 1.13217 train_rmse= 0.82990 val_loss= 1.40993 val_rmse= 0.88244 		time= 2.74201
# [*] Epoch: 3460 train_loss= 1.12814 train_rmse= 0.82955 val_loss= 1.42877 val_rmse= 0.88550 		time= 2.73484
# [*] Epoch: 3461 train_loss= 1.13320 train_rmse= 0.83230 val_loss= 1.44302 val_rmse= 0.88367 		time= 2.74930
# [*] Epoch: 3462 train_loss= 1.12763 train_rmse= 0.82948 val_loss= 1.44881 val_rmse= 0.88475 		time= 2.79067
# [*] Epoch: 3463 train_loss= 1.12980 train_rmse= 0.82896 val_loss= 1.43311 val_rmse= 0.88380 		time= 2.83431
# [*] Epoch: 3464 train_loss= 1.13735 train_rmse= 0.83118 val_loss= 1.38101 val_rmse= 0.88788 		time= 2.72409
# [*] Epoch: 3465 train_loss= 1.13216 train_rmse= 0.83018 val_loss= 1.37184 val_rmse= 0.89396 		time= 2.75179
# [*] Epoch: 3466 train_loss= 1.13197 train_rmse= 0.83257 val_loss= 1.35589 val_rmse= 0.89226 		time= 2.73979
# [*] Epoch: 3467 train_loss= 1.13154 train_rmse= 0.83000 val_loss= 1.35672 val_rmse= 0.88594 		time= 2.71559
# [*] Epoch: 3468 train_loss= 1.13106 train_rmse= 0.83060 val_loss= 1.37506 val_rmse= 0.88557 		time= 2.70701
# [*] Epoch: 3469 train_loss= 1.13002 train_rmse= 0.83081 val_loss= 1.39262 val_rmse= 0.88121 		time= 2.77965
# [*] Epoch: 3470 train_loss= 1.12967 train_rmse= 0.83173 val_loss= 1.42942 val_rmse= 0.88169 		time= 2.73573
# [*] Epoch: 3471 train_loss= 1.13504 train_rmse= 0.83370 val_loss= 1.43306 val_rmse= 0.88545 		time= 2.83120
# [*] Epoch: 3472 train_loss= 1.14841 train_rmse= 0.83856 val_loss= 1.40568 val_rmse= 0.88894 		time= 2.73824
# [*] Epoch: 3473 train_loss= 1.13001 train_rmse= 0.83027 val_loss= 1.38978 val_rmse= 0.88787 		time= 2.79151
# [*] Epoch: 3474 train_loss= 1.13033 train_rmse= 0.83079 val_loss= 1.38638 val_rmse= 0.89106 		time= 2.78857
# [*] Epoch: 3475 train_loss= 1.12881 train_rmse= 0.83004 val_loss= 1.37856 val_rmse= 0.89013 		time= 2.71970
# [*] Epoch: 3476 train_loss= 1.13807 train_rmse= 0.83573 val_loss= 1.37508 val_rmse= 0.89106 		time= 2.73721
# [*] Epoch: 3477 train_loss= 1.12811 train_rmse= 0.82933 val_loss= 1.38519 val_rmse= 0.88671 		time= 2.74878
# [*] Epoch: 3478 train_loss= 1.12674 train_rmse= 0.82861 val_loss= 1.39127 val_rmse= 0.88441 		time= 2.73914
# [*] Epoch: 3479 train_loss= 1.12619 train_rmse= 0.82880 val_loss= 1.40435 val_rmse= 0.88399 		time= 2.74155
# [*] Epoch: 3480 train_loss= 1.12630 train_rmse= 0.82902 val_loss= 1.41637 val_rmse= 0.88366 		time= 2.71590
# [*] Epoch: 3481 train_loss= 1.12605 train_rmse= 0.82842 val_loss= 1.41677 val_rmse= 0.88518 		time= 2.71632
# [*] Epoch: 3482 train_loss= 1.13473 train_rmse= 0.83461 val_loss= 1.39885 val_rmse= 0.88731 		time= 2.70106
# [*] Epoch: 3483 train_loss= 1.13643 train_rmse= 0.83744 val_loss= 1.40457 val_rmse= 0.89008 		time= 2.73351
# [*] Epoch: 3484 train_loss= 1.12828 train_rmse= 0.82850 val_loss= 1.39233 val_rmse= 0.89347 		time= 2.73681
# [*] Epoch: 3485 train_loss= 1.12439 train_rmse= 0.82666 val_loss= 1.38830 val_rmse= 0.89312 		time= 2.72647
# [*] Epoch: 3486 train_loss= 1.13051 train_rmse= 0.83038 val_loss= 1.37856 val_rmse= 0.88916 		time= 2.71692
# [*] Epoch: 3487 train_loss= 1.13838 train_rmse= 0.83471 val_loss= 1.39862 val_rmse= 0.88822 		time= 2.73262
# [*] Epoch: 3488 train_loss= 1.13595 train_rmse= 0.83535 val_loss= 1.41562 val_rmse= 0.88097 		time= 2.70532
# [*] Epoch: 3489 train_loss= 1.13079 train_rmse= 0.83199 val_loss= 1.43368 val_rmse= 0.87792 		time= 2.73458
# [*] Epoch: 3490 train_loss= 1.12937 train_rmse= 0.82941 val_loss= 1.44273 val_rmse= 0.87439 		time= 2.72557
# [*] Epoch: 3491 train_loss= 1.13123 train_rmse= 0.83213 val_loss= 1.45140 val_rmse= 0.87818 		time= 2.70046
# [*] Epoch: 3492 train_loss= 1.13374 train_rmse= 0.83185 val_loss= 1.42629 val_rmse= 0.88247 		time= 2.73917
# [*] Epoch: 3493 train_loss= 1.13606 train_rmse= 0.83230 val_loss= 1.38425 val_rmse= 0.89033 		time= 2.76936
# [*] Epoch: 3494 train_loss= 1.12472 train_rmse= 0.82735 val_loss= 1.35979 val_rmse= 0.89714 		time= 2.71495
# [*] Epoch: 3495 train_loss= 1.13894 train_rmse= 0.83465 val_loss= 1.34957 val_rmse= 0.89923 		time= 2.71714
# [*] Epoch: 3496 train_loss= 1.13658 train_rmse= 0.83020 val_loss= 1.36152 val_rmse= 0.89533 		time= 2.75501
# [*] Epoch: 3497 train_loss= 1.12679 train_rmse= 0.82829 val_loss= 1.36856 val_rmse= 0.88974 		time= 2.71888
# [*] Epoch: 3498 train_loss= 1.12339 train_rmse= 0.82648 val_loss= 1.39492 val_rmse= 0.88182 		time= 2.77694
# [*] Epoch: 3499 train_loss= 1.12616 train_rmse= 0.82801 val_loss= 1.41213 val_rmse= 0.88477 		time= 2.73504
# [*] Epoch: 3500 train_loss= 1.13059 train_rmse= 0.83144 val_loss= 1.40928 val_rmse= 0.88045 		time= 2.70488

# %%
# store model including exponential moving averages
saver = tf.train.Saver()
save_path = saver.save(sess, "tmp/%s.ckpt" % model.name, global_step=model.global_step)

print("\nOptimization Finished!")
print('best validation score =', best_val_score, 'at iteration', best_epoch)

# Testing
test_avg_loss, test_rmse = sess.run([model.loss, model.rmse], feed_dict=test_feed_dict)
print('test loss = ', test_avg_loss)
print('test rmse = ', test_rmse)

# restore with polyak averages of parameters
variables_to_restore = model.variable_averages.variables_to_restore()
saver = tf.train.Saver(variables_to_restore)
saver.restore(sess, save_path)

test_avg_loss, test_rmse = sess.run([model.loss, model.rmse], feed_dict=test_feed_dict)
print('polyak test loss = ', test_avg_loss)
print('polyak test rmse = ', test_rmse)


sess.close()
# Out:
# Optimization Finished!
# best validation score = 0.8714391 at iteration 3433
# test loss =  1.4242109
# test rmse =  0.8879364
# INFO:tensorflow:Restoring parameters from tmp/recommendergae.ckpt-3500
# polyak test loss =  1.392758
# polyak test rmse =  0.8859175
